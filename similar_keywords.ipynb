# %% [markdown]
# ### 1. GOAL
#
# The goal of this task is to find similar keywords, for instance: 'matresses sale' and 'matresses sales'
#
# ### 2. DATA
#
# The data is from excel file organic keywords. We only use first which contains the keywords
#
#
# ### 3. TECHNIQUE SUMMARY
#
#     3.1 Load data
#     3.2 Tokenize and clean data
#     3.3 Find keywords similarity

# %%
# %matplotlib inline

import nltk.data
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams
import string
import textdistance

import pandas as pd
import numpy as np

import time

# %%
# get keywords column from macys_organic_keywords excel file
# this file already modified from the original csv file to make easy to get the keywords
df = pd.read_excel('macys_organic_keywords.xlsx', sheetname='macys_organic_keywords')

# %%
df["Keyword"]
# Out:
# 0                                    mattress sale
# 1                                   mattress sales
# 2                                   mattress deals
# 3                           mattress sales near me
# 4                              macys mattress sale
# 5                              mattresses for sale
# 6                             macy's mattress sale
# 7                                mattress for sale
# 8                            mattress sale near me
# 9                                   macys mattress
# 10                                    matress sale
# 11                              mattresses on sale
# 12                     mattresses for sale near me
# 13                                macys mattresses
# 14                              macy mattress sale
# 15                                   matress sales
# 16                       mattress for sale near me
# 17                                mattress on sale
# 18                              sale on mattresses
# 19                     mattress sales this weekend
# 20                               sales on mattress
# 21                                sale on mattress
# 22                                 macy's mattress
# 23                             best mattress deals
# 24                       macys mattress sale dates
# 25                      mattresses on sale near me
# 26                              macys matress sale
# 27                          mattress deals near me
# 28                              mattress sale macy
# 29                        macys mattresses on sale
#                            ...
# 1560                          how to pick mattress
# 1561                        us mattress.com coupon
# 1562                           usa mattress outlet
# 1563                           twin mattress futon
# 1564                                online matress
# 1565                                sealy vs serta
# 1566                           mattress outlet inc
# 1567                               semi mattresses
# 1568                            best buy en queens
# 1569                  mattress store near me cheap
# 1570                           new mattress online
# 1571                  leesa mattress shipping time
# 1572                king size mattress sale costco
# 1573                   california mattress company
# 1574                          online matress store
# 1575                            full twin mattress
# 1576                              the big mattress
# 1577                       overstock mattress sets
# 1578            queen size mattress box for moving
# 1579                     costco mattress full size
# 1580        how long do pillow top mattresses last
# 1581    can you buy a pillow top for your mattress
# 1582                        luxury mattress online
# 1583                             back to bed store
# 1584               mattress between queen and king
# 1585                     macy's mattress sale 2018
# 1586                          garage sale mattress
# 1587                            buy furniture foam
# 1588                  shopping for mattresses tips
# 1589                  best buy labor day sale 2018
# Name: Keyword, Length: 1590, dtype: object

# %% [markdown]
# ### 3.2 Tokenize and Clean Data

# %%
# tokenize keywords
df["tokenized_keywords"] = df["Keyword"].apply(nltk.word_tokenize)

# %%
# convert dataframe to list of list
tokenized_keywords = df["tokenized_keywords"].values.tolist()

# %%
# Clean keywords
# Convert to lowercase
# Remove punctuation from each word
# Filter out remaining tokens that are not alphabetic
# Filter out tokens that are stop words
# lemmatization
def clean_text(list_tokens):
    #ps = PorterStemmer()
    word_lemma = WordNetLemmatizer()
    cleaned_tokens = list()
    for tokens in list_tokens:
        # convert to lower case
        tokens = [w.lower() for w in tokens]
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove remaining tokens that are not alphabetic
        words = [word for word in stripped if word.isalpha()]
        # filter out stop words
        #nltk.download('stopwords')
        stop_words = set(stopwords.words('english'))
        words = [w for w in words if not w in stop_words]
        # stemming
        # words = [ps.stem (w) for w in words]
        # lemmatize
        # nltk.download('wordnet')
        words = [word_lemma.lemmatize (w) for w in words]
        cleaned_tokens.append(words)
    return cleaned_tokens

# %%
# apply clean_text method to the tokenized_keywords
cleaned_keywords = clean_text(tokenized_keywords)

# %%
cleaned_keywords
# Out:
# [['mattress', 'sale'],
#  ['mattress', 'sale'],
#  ['mattress', 'deal'],
#  ['mattress', 'sale', 'near'],
#  ['macys', 'mattress', 'sale'],
#  ['mattress', 'sale'],
#  ['macy', 'mattress', 'sale'],
#  ['mattress', 'sale'],
#  ['mattress', 'sale', 'near'],
#  ['macys', 'mattress'],
#  ['matress', 'sale'],
#  ['mattress', 'sale'],
#  ['mattress', 'sale', 'near'],
#  ['macys', 'mattress'],
#  ['macy', 'mattress', 'sale'],
#  ['matress', 'sale'],
#  ['mattress', 'sale', 'near'],
#  ['mattress', 'sale'],
#  ['sale', 'mattress'],
#  ['mattress', 'sale', 'weekend'],
#  ['sale', 'mattress'],
#  ['sale', 'mattress'],
#  ['macy', 'mattress'],
#  ['best', 'mattress', 'deal'],
#  ['macys', 'mattress', 'sale', 'date'],
#  ['mattress', 'sale', 'near'],
#  ['macys', 'matress', 'sale'],
#  ['mattress', 'deal', 'near'],
#  ['mattress', 'sale', 'macy'],
#  ['macys', 'mattress', 'sale'],
#  ['macy', 'mattress'],
#  ['mattress', 'sale', 'today'],
#  ['mattress', 'sale', 'macys'],
#  ['bed', 'mattress', 'deal'],
#  ['macy', 'mattress'],
#  ['macy', 'mattress', 'sale', 'coupon'],
#  ['macy', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['macy', 'matress', 'sale'],
#  ['mattress', 'sale', 'today'],
#  ['macy', 'labor', 'day', 'mattress', 'sale'],
#  ['best', 'mattress', 'sale', 'today'],
#  ['mattress', 'deal'],
#  ['mattress', 'macy'],
#  ['matress', 'sale'],
#  ['buy', 'mattress', 'near'],
#  ['mattres', 'sale'],
#  ['sale', 'mattress'],
#  ['best', 'deal', 'mattress'],
#  ['mattress', 'clearance', 'sale'],
#  ['macys', 'furniture', 'mattress'],
#  ['matress', 'deal'],
#  ['mattress', 'special'],
#  ['macys', 'matress'],
#  ['macys', 'mattress', 'sale'],
#  ['single', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['best', 'matress', 'deal'],
#  ['best', 'mattress', 'deal', 'near'],
#  ['macy', 'mattress', 'sale'],
#  ['macy', 'mattress', 'sale', 'date'],
#  ['macy', 'mattress', 'clearance'],
#  ['mattress', 'sale', 'near'],
#  ['macy', 'columbus', 'day', 'mattress', 'sale'],
#  ['macy', 'mattress', 'sale'],
#  ['deal', 'mattress'],
#  ['mattress', 'sale', 'nyc'],
#  ['macy', 'furniture', 'mattress', 'sale'],
#  ['macys', 'mattress', 'sale'],
#  ['macy', 'mattress', 'sale'],
#  ['best', 'deal', 'mattress'],
#  ['macy', 'one', 'day', 'mattress', 'sale'],
#  ['macys', 'furniture', 'mattress'],
#  ['macy', 'july', 'mattress', 'sale'],
#  ['new', 'mattress', 'sale'],
#  ['sale', 'mattress'],
#  ['mattress', 'sale', 'area'],
#  ['macys', 'matresses'],
#  ['bed', 'sale', 'near'],
#  ['macys', 'mattress', 'sale'],
#  ['buy', 'mattress'],
#  ['mattress', 'sale', 'macys'],
#  ['mattress', 'sale', 'weekend'],
#  ['macy', 'mattress', 'sale', 'today'],
#  ['macys', 'mattress', 'store'],
#  ['matress', 'sale', 'near'],
#  ['best', 'mattress', 'sale'],
#  ['macy', 'mattress'],
#  ['macy', 'mattress', 'outlet'],
#  ['sale', 'mattress'],
#  ['macy', 'bed', 'mattress', 'sale'],
#  ['veteran', 'day', 'mattress', 'sale'],
#  ['mattresssale'],
#  ['matresses', 'sale'],
#  ['mattress', 'sale'],
#  ['matresses', 'sale'],
#  ['mattress', 'macys'],
#  ['sleep', 'train', 'mattress', 'sale'],
#  ['matress', 'sale', 'near'],
#  ['deal', 'mattress', 'near'],
#  ['christmas', 'mattress', 'sale'],
#  ['mattress'],
#  ['macy', 'memorial', 'day', 'mattress', 'sale'],
#  ['macy', 'bed', 'mattress'],
#  ['mattress', 'store', 'sale'],
#  ['best', 'mattress', 'sale'],
#  ['mattress', 'sell'],
#  ['mattress', 'special', 'near'],
#  ['best', 'mattress', 'sale', 'weekend'],
#  ['mattress', 'store', 'sale'],
#  ['buy', 'mattress', 'near'],
#  ['mattress', 'discount', 'near'],
#  ['sale', 'mattress'],
#  ['macy', 'matress'],
#  ['veteran', 'day', 'mattress', 'sale'],
#  ['macys', 'mattress', 'full'],
#  ['bed', 'mattress', 'sale', 'near'],
#  ['best', 'time', 'buy', 'mattress', 'macy'],
#  ['memorial', 'day', 'mattress', 'sale'],
#  ['discount', 'mattress', 'set'],
#  ['macys', 'mattress', 'store'],
#  ['bed', 'mattress', 'sale', 'near'],
#  ['best', 'mattress', 'sale', 'today'],
#  ['macys', 'com', 'mattress', 'sale'],
#  ['matte', 'sale'],
#  ['end', 'year', 'mattress', 'sale'],
#  ['macy', 'bed', 'sale'],
#  ['macy', 'veteran', 'day', 'mattress', 'sale'],
#  ['matress', 'sale'],
#  ['macy', 'black', 'friday', 'mattress', 'sale'],
#  ['macys', 'com', 'mattress'],
#  ['buy', 'mattress', 'near'],
#  ['mattress', 'best', 'deal'],
#  ['place', 'sell', 'mattress', 'near'],
#  ['mattress', 'set', 'sale', 'near'],
#  ['columbus', 'day', 'mattress', 'sale'],
#  ['best', 'mattress', 'deal'],
#  ['great', 'mattress', 'deal'],
#  ['mattres', 'mattres'],
#  ['mattress', 'sell'],
#  ['bed', 'mattress', 'sale'],
#  ['best', 'deal', 'mattress'],
#  ['firm', 'mattress', 'sale'],
#  ['best', 'deal', 'mattress', 'near'],
#  ['buy', 'mattress', 'near'],
#  ['best', 'mattress', 'sale', 'weekend'],
#  ['mattress', 'macy'],
#  ['best', 'mattress', 'deal', 'today'],
#  ['mattress', 'set', 'deal'],
#  ['bed', 'special'],
#  ['macy', 'mattress', 'outlet'],
#  ['mattress', 'sale'],
#  ['mattress', 'macys', 'sale'],
#  ['mattress', 'sale', 'week'],
#  ['mattress', 'sale', 'today'],
#  ['bed', 'sale', 'weekend'],
#  ['sale', 'bed', 'mattress'],
#  ['best', 'deal', 'bed', 'mattress'],
#  ['macy', 'mattress', 'sale'],
#  ['memorial', 'day', 'mattress', 'sale'],
#  ['mattress', 'macys'],
#  ['macys', 'bed', 'sale'],
#  ['best', 'mattress', 'sale', 'near'],
#  ['store', 'sell', 'mattress', 'near'],
#  ['mattress', 'sale', 'near', 'location'],
#  ['bed', 'sale', 'near'],
#  ['mattress', 'deal', 'today'],
#  ['sale', 'mattress', 'near'],
#  ['current', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['mattress', 'sale', 'area'],
#  ['macy', 'queen', 'mattress'],
#  ['mattress', 'store', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['good', 'deal', 'mattress'],
#  ['macy', 'mattress', 'sale', 'queen'],
#  ['mattress', 'sale'],
#  ['best', 'mattress', 'price', 'near'],
#  ['christmas', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['best', 'deal', 'mattress'],
#  ['mattres', 'sale'],
#  ['macy', 'mattress', 'sale', 'full', 'size'],
#  ['bed', 'mattress', 'deal'],
#  ['affordable', 'mattress', 'near'],
#  ['bed', 'matress', 'sale'],
#  ['macy', 'venta', 'de', 'colchones'],
#  ['mattress', 'mattress'],
#  ['bed', 'mattress', 'sale'],
#  ['mattress', 'sale', 'free', 'delivery'],
#  ['mattress', 'free', 'delivery'],
#  ['mattress', 'firm', 'veteran', 'day', 'sale'],
#  ['macy', 'president', 'day', 'mattress', 'sale'],
#  ['macy', 'mattress', 'department'],
#  ['mattress', 'bed', 'sale'],
#  ['mattress', 'macy'],
#  ['top', 'mattress', 'deal'],
#  ['macy', 'full', 'size', 'mattress'],
#  ['discount', 'mattress', 'near'],
#  ['mattress', 'sale', 'veteran', 'day'],
#  ['single', 'bed', 'mattress', 'sale'],
#  ['sell', 'mattress'],
#  ['mattress', 'bed', 'sale'],
#  ['mattress', 'firm', 'sale', 'weekend'],
#  ['sale', 'mattress'],
#  ['best', 'mattress', 'sale'],
#  ['new', 'mattress', 'sale'],
#  ['macy', 'mattress', 'sale', 'king', 'size'],
#  ['best', 'deal', 'mattress'],
#  ['mattress', 'sa'],
#  ['double', 'bed', 'mattress', 'sale'],
#  ['macys', 'mattress', 'sale'],
#  ['macy', 'mattress', 'black', 'friday', 'sale'],
#  ['macy', 'mattress', 'store'],
#  ['macy', 'mattress', 'queen'],
#  ['good', 'mattress', 'sale'],
#  ['mattress', 'firm', 'mattress', 'sale'],
#  ['foam', 'mattress', 'sale'],
#  ['macy', 'bed', 'sale'],
#  ['mattress', 'free', 'shipping'],
#  ['macy', 'twin', 'mattress', 'sale'],
#  ['mattress', 'firm', 'special'],
#  ['looking', 'mattress', 'sale'],
#  ['bed', 'deal', 'near'],
#  ['mattress', 'sale', 'free', 'delivery'],
#  ['cheapest', 'mattress', 'near'],
#  ['best', 'price', 'mattress', 'near'],
#  ['columbus', 'day', 'mattress', 'sale'],
#  ['matress', 'deal'],
#  ['mismatch', 'mattress', 'sale'],
#  ['best', 'price', 'mattress'],
#  ['good', 'mattress', 'deal'],
#  ['mattress', 'clearance', 'near'],
#  ['mattress', 'sale', 'free', 'shipping'],
#  ['new', 'mattress', 'near'],
#  ['macys', 'mattress', 'outlet'],
#  ['macy', 'mattress', 'set', 'sale'],
#  ['closeout', 'mattress', 'sale'],
#  ['king', 'mattress', 'sale', 'near'],
#  ['new', 'year', 'mattress', 'sale'],
#  ['cheap', 'mattress', 'sale'],
#  ['bed', 'mattress', 'deal'],
#  ['macy', 'mattress', 'set'],
#  ['best', 'mattress', 'sale'],
#  ['queen', 'mattress', 'macys'],
#  ['mattress', 'discount', 'store', 'near'],
#  ['bed', 'mattress', 'sale'],
#  ['mattress', 'firm', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['mattress', 'store', 'near'],
#  ['sale', 'bed', 'mattress'],
#  ['mattress'],
#  ['best', 'mattress', 'sale'],
#  ['mattress', 'macys'],
#  ['matteress', 'sale'],
#  ['buy', 'mattress', 'near'],
#  ['best', 'sale', 'mattress'],
#  ['matresses', 'near'],
#  ['bed', 'mattress', 'sale'],
#  ['best', 'deal', 'mattress', 'set'],
#  ['firm', 'mattress', 'near'],
#  ['easter', 'mattress', 'sale'],
#  ['macy', 'mattress', 'sale'],
#  ['mattress', 'sale', 'around'],
#  ['labor', 'day', 'mattress', 'sale'],
#  ['mattress', 'firm', 'clearance', 'near'],
#  ['big', 'mattress', 'sale'],
#  ['mattress', 'department'],
#  ['bed', 'sale', 'today'],
#  ['mattress', 'outlet', 'near'],
#  ['best', 'deal', 'mattress'],
#  ['venta', 'de', 'colchones', 'en', 'macy'],
#  ['discount', 'mattress', 'sale'],
#  ['new', 'mattress', 'sale'],
#  ['macy', 'bed', 'mattress'],
#  ['macys', 'mattress', 'queen'],
#  ['new', 'year', 'mattress', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['mattress', 'sale'],
#  ['sale', 'mattress'],
#  ['sale', 'bed', 'mattress'],
#  ['best', 'price', 'matresses'],
#  ['mattress', 'sale', 'denver'],
#  ['cheap', 'bed', 'mattress', 'included'],
#  ['macys', 'mattress', 'twin'],
#  ['cheap', 'mattress', 'near'],
#  ['president', 'day', 'mattress', 'sale'],
#  ['bed', 'sale', 'nyc'],
#  ['mattress', 'king', 'tulsa'],
#  ['matress', 'near'],
#  ['foam', 'mattress', 'near'],
#  ['special', 'mattress'],
#  ['macy', 'mattress', 'store', 'locator'],
#  ['mattress', 'sale', 'portland'],
#  ['new', 'mattress', 'sale', 'cheap'],
#  ['mattress', 'store', 'free', 'delivery'],
#  ['mattress', 'sale', 'memorial', 'day'],
#  ['top', 'mattress', 'sale'],
#  ['biggest', 'mattress', 'sale'],
#  ['macy', 'mattress'],
#  ['best', 'mattress', 'sale'],
#  ['macys', 'mattress', 'set'],
#  ['upcoming', 'mattress', 'sale'],
#  ['deal', 'mattress'],
#  ['bed', 'mattress', 'near'],
#  ['queen', 'mattress', 'clearance', 'free', 'shipping'],
#  ['brand', 'new', 'mattress', 'sale'],
#  ['macys', 'mattress', 'queen'],
#  ['full', 'size', 'mattress', 'sale', 'near'],
#  ['memorial', 'day', 'mattress', 'sale'],
#  ['mattress', 'today'],
#  ['mattress', 'store', 'near'],
#  ['mattress', 'sale', 'going'],
#  ['mattress', 'clearance', 'store'],
#  ['best', 'mattress', 'deal', 'weekend'],
#  ['mattress', 'discount', 'store', 'near'],
#  ['memorial', 'day', 'mattress', 'sale', 'near'],
#  ['cheap', 'mattress', 'sale'],
#  ['king', 'mattress', 'clearance', 'sale'],
#  ['cheap', 'mattress', 'set', 'near'],
#  ['mattress', 'firm', 'semi', 'annual', 'sale'],
#  ['bed', 'mattress', 'sale'],
#  ['queen', 'mattress', 'set', 'sale', 'free', 'shipping'],
#  ['mattress', 'lowest', 'price'],
#  ['show', 'mattress'],
#  ['new', 'year', 'mattress', 'sale'],
#  ['mattress', 'sale'],
#  ['mattress', 'sale', 'price'],
#  ['cheapest', 'mattress', 'near'],
#  ['mattress', 'firm', 'clearance', 'store'],
#  ['columbus', 'day', 'mattress', 'sale'],
#  ['next', 'mattress'],
#  ['macy', 'mattress', 'clearance'],
#  ['free', 'delivery', 'mattress'],
#  ['bed', 'mattress', 'set', 'sale'],
#  ['mother', 'day', 'mattress', 'sale'],
#  ['mattress', 'discount', 'store'],
#  ['full', 'mattress', 'sale', 'free', 'shipping'],
#  ['find', 'mattress', 'sale'],
#  ['mismatched', 'mattress', 'sale'],
#  ['mattress', 'sale', 'online'],
#  ['mismatched', 'mattress', 'set'],
#  ['day', 'mattress'],
#  ['mattress', 'sale', 'online'],
#  ['mattress', 'store', 'around'],
#  ['cheap', 'mattress', 'store', 'near'],
#  ['macy', 'queen', 'mattress', 'set', 'sale'],
#  ['macys', 'full', 'size', 'mattress'],
#  ['mattress', 'base', 'sale'],
#  ['mattress', 'sale', 'memorial', 'day'],
#  ['buy', 'mattress', 'near'],
#  ['mattress', 'store', 'near'],
#  ['bed', 'mattress', 'deal'],
#  ['mattress', 'clearance', 'houston'],
#  ['mattress', 'sale'],
#  ['mattress', 'clearance', 'outlet'],
#  ['holiday', 'mattress', 'sale'],
#  ['bed', 'mattress', 'deal'],
#  ['best', 'place', 'buy', 'mattress', 'near'],
#  ['mattress', 'sale', 'pa'],
#  ['mattress', 'one', 'veteran', 'day', 'sale'],
#  ['labor', 'day', 'mattress', 'sale'],
#  ['cheap', 'bed', 'mattress', 'sale'],
#  ['memorial', 'mattress', 'sale'],
#  ['mattress', 'clearance', 'usa'],
#  ['store', 'sell', 'mattress'],
#  ['queen', 'size', 'mattress', 'macys'],
#  ['memorial', 'day', 'mattress', 'sale'],
#  ['looking', 'mattress'],
#  ['mattress', 'veteran', 'day', 'sale'],
#  ['queen', 'mattress', 'set', 'mattress', 'firm'],
#  ['bed', 'mattress', 'set', 'sale'],
#  ['memorial', 'day', 'mattress', 'sale'],
#  ['firm', 'bed', 'sale'],
#  ['best', 'price', 'mattress'],
#  ['mattress', 'buy'],
#  ['mattress', 'sale', 'houston'],
#  ['best', 'price', 'mattress'],
#  ['mattress', 'sale', 'cheap'],
#  ['firm', 'mattress', 'deal'],
#  ['mattress', 'online', 'free', 'shipping'],
#  ['mattress', 'sale', 'memorial', 'day'],
#  ['mismatch', 'mattress'],
#  ['mattress', 'sale', 'labor', 'day'],
#  ['best', 'matress', 'sale'],
#  ['place', 'sell', 'mattress'],
#  ['holiday', 'mattress', 'sale'],
#  ['bed', 'sale', 'mattress'],
#  ['mattress'],
#  ['mattress', 'sale'],
#  ['discount', 'mattress', 'store', 'near'],
#  ['mattress', 'store', 'sale'],
#  ['good', 'deal', 'bed', 'mattress'],
#  ['bed', 'sale', 'free', 'delivery'],
#  ['bed', 'mattress', 'sale', 'cheap'],
#  ['low', 'price', 'mattress', 'sale'],
#  ['cheap', 'bed', 'mattress', 'deal'],
#  ['discount', 'mattress', 'set', 'near'],
#  ['mattress', 'sale'],
#  ['cheapest', 'mattress', 'store', 'near'],
#  ['memorial', 'day', 'matress', 'sale'],
#  ['mattress', 'tv', 'deal'],
#  ['mattress', 'delivery', 'near'],
#  ['mattress', 'free', 'delivery'],
#  ['discount', 'bed', 'mattress'],
#  ['shop', 'mattress', 'near'],
#  ['discounted', 'mattress'],
#  ['mattress', 'sale', 'online'],
#  ['memorial', 'day', 'sale', 'mattress'],
#  ['buy', 'mattress', 'near'],
#  ['buy', 'cheap', 'mattress', 'near'],
#  ['discounted', 'mattress'],
#  ['macys', 'mattress', 'king'],
#  ['veteran', 'day', 'sale', 'mattress'],
#  ['mattress', 'firm', 'year', 'end', 'sale'],
#  ['best', 'mattress', 'store', 'near'],
#  ['mattress', 'online', 'free', 'shipping'],
#  ['veteran', 'day', 'sale', 'mattress'],
#  ['queen', 'mattress', 'set', 'free', 'delivery'],
#  ['good', 'deal', 'mattress'],
#  ['mattress', 'sale', 'near'],
#  ['cheapest', 'mattress', 'price'],
#  ['mattress', 'sale', 'online', 'free', 'delivery'],
#  ['macy', 'mattress', 'queen'],
#  ['mattress', 'firm', 'closeout'],
#  ['macy', 'queen', 'mattress'],
#  ['mattress', 'sale', 'okc'],
#  ['mattress', 'firm', 'clearance', 'center', 'houston'],
#  ['mattress', 'bed', 'sale'],
#  ['best', 'mattress', 'near'],
#  ['mattress', 'sale', 'nearby'],
#  ['best', 'price', 'mattress', 'set'],
#  ['cheap', 'new', 'mattress', 'near'],
#  ['mattress', 'doorbuster'],
#  ['mattress'],
#  ['discount', 'mattress', 'near'],
#  ['houston', 'discount', 'mattress'],
#  ['mattress', 'sale', 'free', 'tv'],
#  ['mattress', 'place', 'near'],
#  ['buy', 'cheap', 'mattress'],
#  ['mattress', 'set', 'free', 'delivery'],
#  ['cheap', 'bed', 'mattress', 'sale'],
#  ['w', 'mattress', 'sale'],
#  ['mattress', 'set', 'free', 'delivery'],
#  ['queen', 'mattress', 'sale', 'free', 'delivery'],
#  ['mattress', 'sale', 'online'],
#  ['cheap', 'mattress', 'online', 'free', 'shipping'],
#  ['bed', 'mattress', 'near'],
#  ['discounted', 'mattress', 'near'],
#  ['mattress', 'firm', 'columbus', 'day', 'sale'],
#  ['free', 'shipping', 'mattress'],
#  ['cheap', 'bed', 'mattress', 'sale'],
#  ['bed', 'plus', 'mattress', 'sale'],
#  ['best', 'price', 'mattress'],
#  ['king', 'mattress', 'near'],
#  ['quality', 'mattress', 'sale'],
#  ['cheapest', 'mattress', 'sale'],
#  ['mattress', 'sale', 'online'],
#  ['memorial', 'day', 'sale', 'mattress'],
#  ['cheap', 'mattress', 'free', 'delivery'],
#  ['cheap', 'bed', 'mattress', 'set'],
#  ['mattress', 'sale', 'columbus', 'day'],
#  ['mattress'],
#  ['mattress', 'sale', 'mn'],
#  ['discount', 'mattress', 'free', 'shipping'],
#  ['bed', 'mattress', 'included', 'sale'],
#  ['cheap', 'bed', 'sale', 'mattress'],
#  ['low', 'cost', 'mattress', 'set'],
#  ['twin', 'mattress', 'set', 'mattress', 'firm'],
#  ['discount', 'bed', 'mattress'],
#  ['free', 'tv', 'mattress', 'purchase'],
#  ['mattress', 'free', 'shipping'],
#  ['get', 'best', 'deal', 'mattress'],
#  ['mattress', 'memorial', 'day', 'sale'],
#  ['mattress', 'firm', 'memorial', 'day', 'sale'],
#  ['clearance', 'mattress', 'box', 'spring'],
#  ['mattress', 'sale', 'cheap'],
#  ['cheap', 'name', 'brand', 'mattress'],
#  ['mattress', 'online', 'sale'],
#  ['best', 'price', 'mattress'],
#  ['buy', 'mattress', 'online', 'free', 'shipping'],
#  ['discount', 'mattress', 'online', 'free', 'delivery'],
#  ['president', 'sale', 'mattress'],
#  ['bed', 'mattress', 'deal'],
#  ['bed', 'mattress', 'sale'],
#  ['cheap', 'mattress', 'deal'],
#  ['labor', 'day', 'mattress', 'sale'],
#  ['mattress', 'firm', 'labor', 'day', 'sale'],
#  ['cheap', 'bed', 'mattress', 'sale'],
#  ['buy', 'mattress', 'set'],
#  ['mattress', 'offer', 'online'],
#  ['new', 'mattress', 'set'],
#  ['mattress', 'labor', 'day', 'sale'],
#  ['sell', 'bed', 'mattress'],
#  ['cheap', 'bed', 'mattress', 'set'],
#  ['mattress', 'sale'],
#  ['bed', 'matress', 'set'],
#  ['veteran', 'day', 'bed', 'sale'],
#  ['macys', 'sa'],
#  ['best', 'mattress', 'offer'],
#  ['memorial', 'day', 'matress', 'sale'],
#  ['mattress', 'king', 'memorial', 'day', 'sale'],
#  ['buy', 'mattress', 'cheap'],
#  ['best', 'sale', 'mattress'],
#  ['google', 'mattress'],
#  ['mismatched', 'mattress'],
#  ['mattress', 'sale', 'houston', 'tx'],
#  ['columbus', 'day', 'bed', 'sale'],
#  ['queen', 'mattress', 'set', 'free', 'shipping'],
#  ['best', 'memorial', 'day', 'mattress', 'sale'],
#  ['bed', 'deal'],
#  ['cheapest', 'place', 'buy', 'mattress', 'set'],
#  ['best', 'bed', 'sale'],
#  ['cheap', 'mattress', 'free', 'shipping'],
#  ['cheap', 'mattress', 'set'],
#  ['bed', 'mattress', 'set', 'cheap'],
#  ['best', 'price', 'mattress', 'set'],
#  ['mattress', 'nearby'],
#  ['discount', 'mattress', 'online'],
#  ['best', 'price', 'mattress'],
#  ['full', 'mattress', 'free', 'shipping'],
#  ['mattress', 'sale', 'cleveland', 'ohio'],
#  ['premium', 'mattress', 'outlet'],
#  ['matress', 'firm', 'near'],
#  ['get', 'best', 'mattress', 'deal'],
#  ['looking', 'mattress'],
#  ['online', 'mattress', 'deal'],
#  ['full', 'size', 'mattress', 'set', 'free', 'delivery'],
#  ['tss', 'warehouse', 'coupon'],
#  ['mattress', 'outlet', 'online'],
#  ['price', 'mattress'],
#  ['president', 'day', 'mattress', 'sale'],
#  ['free', 'mattress', 'delivery'],
#  ['cheap', 'double', 'mattress', 'sale'],
#  ['labor', 'day', 'mattress', 'sale'],
#  ['mattress', 'clearance', 'chicago'],
#  ['denver', 'discount', 'mattress'],
#  ['low', 'price', 'mattress'],
#  ['discount', 'mattress', 'online'],
#  ['sell', 'cheapest', 'mattress'],
#  ['mattress', 'sale', 'cheap'],
#  ['buy', 'mattress', 'cheap'],
#  ['buy', 'discount', 'mattress'],
#  ['july', 'mattress', 'sale'],
#  ['best', 'buy', 'closeout'],
#  ['mattress', 'sale', 'cheap', 'price'],
#  ['bed', 'mattress', 'set'],
#  ['new', 'bed', 'mattress', 'price'],
#  ['purchase', 'mattress', 'near'],
#  ['day', 'mattress'],
#  ['cheap', 'full', 'mattress', 'near'],
#  ['mattress', 'sale', 'dfw'],
#  ['cheapest', 'mattress'],
#  ['cheap', 'new', 'mattress', 'boxspring', 'set'],
#  ['memorial', 'day', 'sale', 'mattress'],
#  ['mattress', 'delivery', 'seattle'],
#  ['best', 'place', 'buy', 'mattress', 'near'],
#  ['cheapest', 'bed', 'mattress'],
#  ['best', 'price', 'mattress'],
#  ['mattress', 'firm', 'sale', 'ad'],
#  ['cheap', 'mattress', 'near'],
#  ['macy', 'bed', 'sale'],
#  ['mattres'],
#  ['best', 'price', 'mattress'],
#  ['cheapest', 'mattress', 'store'],
#  ['cheapest', 'bed', 'sale'],
#  ['lowest', 'price', 'mattress'],
#  ['mattress', 'firm', 'clearance', 'outlet'],
#  ['tempurpedic', 'mattress', 'closeout', 'sale'],
#  ['king', 'size', 'mattress', 'free', 'shipping'],
#  ['cheapest', 'full', 'mattress'],
#  ['memory', 'foam', 'mattress', 'sale', 'near'],
#  ['biggest', 'mattress', 'sale', 'year'],
#  ['mattress', 'warehouse', 'president', 'day', 'sale'],
#  ['mattress', 'outlet', 'seattle'],
#  ['buy', 'mattress', 'cheap'],
#  ['mattress', 'deal', 'online'],
#  ['warehouse', 'clearance', 'mattress'],
#  ['mattress', 'around'],
#  ['premium', 'mattress', 'outlet', 'inc'],
#  ['mattress', 'firm', 'doorbuster'],
#  ['mattress', 'warehouse', 'nyc'],
#  ['mattress', 'base', 'sale'],
#  ['discount', 'boxspring'],
#  ['mattress', 'warehouse', 'mattress', 'sale'],
#  ['best', 'deal', 'mattress', 'furniture'],
#  ['twin', 'mattress', 'okc'],
#  ['buy', 'cheap', 'bed', 'mattress'],
#  ['mattress', 'firm', 'clearance'],
#  ['best', 'mattress', 'store', 'near'],
#  ['mattress', 'clearance', 'dallas'],
#  ['buy', 'cheap', 'mattress', 'near'],
#  ['mattress', 'firm', 'memorial', 'day', 'sale'],
#  ['discount', 'mattress', 'boxspring', 'set'],
#  ['cheap', 'bed', 'mattress', 'deal'],
#  ['mattress', 'firm', 'doorbuster', 'sale'],
#  ['denver', 'mattress', 'president', 'day', 'sale'],
#  ['sell', 'mattress', 'cheap'],
#  ['matteress'],
#  ['mattress', 'sale'],
#  ['mattress', 'sale', 'denver'],
#  ['cheapest', 'mattress'],
#  ['mattress', 'warehouse', 'tucson'],
#  ['denver', 'mattress', 'memorial', 'day', 'sale'],
#  ['memorial', 'weekend', 'mattress', 'sale'],
#  ['mattress', 'sale', 'online', 'free', 'shipping'],
#  ['mattress', 'firm', 'labor', 'day', 'sale'],
#  ['twin', 'mattress', 'sale', 'houston'],
#  ['memory', 'foam', 'mattress', 'free', 'shipping'],
#  ['cheapest', 'place', 'buy', 'mattress', 'box', 'spring'],
#  ['mattress', 'warehouse', 'sale'],
#  ['full', 'mattress', 'free', 'delivery'],
#  ['online', 'mattress', 'sale'],
#  ['mattressnow'],
#  ['cheap', 'bed', 'seattle'],
#  ['cheap', 'new', 'bed', 'near'],
#  ['mattress', 'store'],
#  ['buy', 'cheap', 'mattress'],
#  ['macys', 'sale', 'today'],
#  ['discount', 'mattress', 'baltimore'],
#  ['cheap', 'bed', 'mattress', 'deal'],
#  ['cheap', 'new', 'mattress', 'set'],
#  ['mattress', 'firm', 'back', 'school', 'sale'],
#  ['bed', 'sale', 'houston'],
#  ['cheapest', 'place', 'buy', 'mattress', 'set'],
#  ['mattress', 'firm', 'king', 'size', 'mattress', 'price'],
#  ['mattress', 'discount', 'store'],
#  ['best', 'place', 'buy', 'mattress', 'near'],
#  ['bed', 'mattress', 'cheap'],
#  ['cheapest', 'full', 'mattress', 'set'],
#  ['affordable', 'mattress', 'nyc'],
#  ['memorial', 'day', 'sale', 'mattress'],
#  ['mattress', 'warehouse', 'san', 'antonio'],
#  ['mattress', 'sale'],
#  ['mattress', 'sale', 'denver', 'co'],
#  ['firm', 'mattress', 'discount'],
#  ['mattress', 'store', 'near', 'deliver'],
#  ['cheapest', 'bed', 'mattress'],
#  ['mattress', 'store'],
#  ['mattress', 'online', 'free', 'delivery'],
#  ['full', 'size', 'bed', 'delivery'],
#  ['denver', 'mattress', 'labor', 'day', 'sale'],
#  ['sleep', 'train', 'president', 'day', 'sale'],
#  ['serta', 'president', 'day', 'sale'],
#  ['single', 'mattress', 'sale'],
#  ['foam', 'mattress', 'clearance'],
#  ['best', 'mattress', 'sale'],
#  ['discount', 'mattress', 'firm'],
#  ['best', 'place', 'buy', 'mattress'],
#  ['cheap', 'mattress', 'sale', 'near'],
#  ['mattress', 'warehouse', 'clearance', 'outlet'],
#  ['mattress', 'firm', 'memorial', 'day', 'sale'],
#  ['cheap', 'discount', 'mattress'],
#  ['discount', 'mattress', 'okc'],
#  ['mattress', 'firm', 'president', 'sale'],
#  ['bed', 'mattress', 'cheap'],
#  ['cheapest', 'bed', 'mattress'],
#  ['queen', 'mattress', 'store'],
#  ['best', 'place', 'buy', 'mattress', 'set'],
#  ['bed', 'mattress', 'set', 'deal'],
#  ['new', 'mattress', 'set'],
#  ['free', 'mattress', 'near'],
#  ['mattress', 'sale', 'okc'],
#  ['sleep', 'train', 'mattress', 'sale'],
#  ['buy', 'bed', 'mattress'],
#  ['mattress', 'firm', 'july', 'sale'],
#  ['mattress', 'cheap', 'price'],
#  ['mattress', 'king', 'tulsa', 'hill'],
#  ['online', 'mattress', 'store', 'free', 'delivery'],
#  ['mattress', 'sale', 'cleveland'],
#  ['sleepy', 'mattress', 'deal'],
#  ['tucson', 'mattress', 'sale'],
#  ['super', 'single', 'mattress', 'sale'],
#  ['cheapest', 'place', 'mattress'],
#  ['la', 'vega', 'mattress', 'outlet'],
#  ['mattress', 'sale', 'portland'],
#  ['mattress', 'firm', 'clearance', 'houston', 'tx'],
#  ['memory', 'foam', 'near'],
#  ['mattress', 'sale'],
#  ['best', 'price', 'mattress', 'set'],
#  ['cheap', 'bed', 'mattress', 'set'],
#  ['houston', 'mattress', 'sale'],
#  ['mattress', 'firm', 'deal'],
#  ['best', 'price', 'mattress'],
#  ['queen', 'box', 'spring', 'sale', 'near'],
#  ['buy', 'mattress', 'cheap'],
#  ['bed', 'mattress', 'set'],
#  ['mattress', 'warehouse', 'black', 'friday', 'sale'],
#  ['best', 'price', 'mattress', 'box', 'spring'],
#  ['small', 'mattress', 'sale'],
#  ['buy', 'cheap', 'mattress', 'online', 'free', 'shipping'],
#  ['mattress', 'sale', 'denver'],
#  ['single', 'mattress', 'near'],
#  ['labor', 'day', 'sale', 'mattress'],
#  ['best', 'buy', 'mattress'],
#  ['mattress', 'one', 'sale'],
#  ['cheap', 'queen', 'mattress', 'set', 'near'],
#  ['best', 'price', 'mattress', 'set'],
#  ['best', 'mattress', 'queen'],
#  ['mattress', 'firm', 'july', 'sale'],
#  ['leesa', 'mattress', 'nyc'],
#  ['mattress', 'firm', 'clearance', 'center', 'san', 'antonio'],
#  ['sealy', 'futon'],
#  ['macy', 'foam', 'mattress'],
#  ['cheap', 'bed', 'mattress', 'sale'],
#  ['discount', 'mattress', 'houston'],
#  ['top', 'mattress', 'store'],
#  ['mattress', 'king'],
#  ['mattress', 'queen'],
#  ['buy', 'mattress', 'set', 'online'],
#  ['mattress', 'sale', 'memorial', 'day'],
#  ['sealy', 'mattress', 'warehouse'],
#  ['macys', 'bedding', 'sale'],
#  ['mattress', 'close'],
#  ['mattress', 'king', 'chicago'],
#  ['discount', 'mattress', 'tulsa'],
#  ['mattress', 'warehouse', 'houston', 'tx'],
#  ['king', 'size', 'mattress', 'set'],
#  ['buy', 'mattress', 'cheap'],
#  ['cheap', 'mattress', 'area'],
#  ['mattress', 'firm', 'fourth', 'july', 'sale'],
#  ['mattress', 'firm', 'louisville'],
#  ['best', 'labor', 'day', 'mattress', 'sale'],
#  ['mattress', 'one', 'memorial', 'day', 'sale'],
#  ['mattress', 'firm', 'columbus'],
#  ['best', 'mattress', 'set'],
#  ['buy', 'cheap', 'mattress', 'set'],
#  ['serta', 'mattress', 'warehouse'],
#  ['cheap', 'bed', 'mattress', 'deal'],
#  ['best', 'buy', 'mattress', 'sale'],
#  ['discount', 'mattress', 'la', 'vega'],
#  ['july', 'mattress', 'sale'],
#  ['inexpensive', 'mattress', 'near'],
#  ['mattress', 'firm', 'near'],
#  ['foam', 'mattress', 'discount'],
#  ['cheap', 'bed', 'matress', 'deal'],
#  ['mattress', 'warehouse', 'san', 'diego'],
#  ['cheap', 'single', 'mattress', 'sale'],
#  ['looking', 'cheap', 'mattress'],
#  ['best', 'price', 'matress'],
#  ['mattress', 'sale', 'labor', 'day'],
#  ['futon', 'nyc', 'free', 'delivery'],
#  ['mattress', 'sale', 'jacksonville'],
#  ['bed', 'mattress', 'set'],
#  ['sealy', 'futon', 'collection'],
#  ['full', 'mattress', 'delivery'],
#  ['discount', 'mattress', 'denver'],
#  ['cheap', 'mattress', 'set', 'cleveland', 'ohio'],
#  ['brand', 'new', 'mattress', 'cheap'],
#  ['okc', 'mattress', 'sale'],
#  ['biggest', 'mattress'],
#  ['mattress', 'firm', 'sale', 'ad'],
#  ['full', 'mattress', 'online'],
#  ['best', 'price', 'mattress'],
#  ['mattress', 'one', 'clearance'],
#  ['bed', 'mattress', 'cheap'],
#  ['memorial', 'day', 'sale', 'mattress'],
#  ['cheap', 'mattress', 'firm'],
#  ['labor', 'day', 'mattress', 'sale'],
#  ['queen', 'mattress', 'set'],
#  ['u', 'mattress', 'memorial', 'day', 'sale'],
#  ['mattress', 'firm', 'clearance', 'jacksonville', 'fl'],
#  ['foam', 'mattress', 'store', 'near'],
#  ['cheapest', 'place', 'buy', 'mattress', 'set'],
#  ['best', 'priced', 'mattress'],
#  ['memorial', 'day', 'mattress', 'sale'],
#  ['cheapest', 'mattress'],
#  ['best', 'time', 'buy', 'mattress', 'box', 'spring'],
#  ['president', 'day', 'sale', 'mattress'],
#  ['buy', 'cheap', 'mattress', 'near'],
#  ['queen', 'mattress', 'online'],
#  ['memorial', 'day', 'weekend', 'mattress', 'sale'],
#  ['houston', 'discount', 'mattress'],
#  ['inexpensive', 'mattress', 'sale'],
#  ['futon', 'mattress', 'dollar'],
#  ['cheap', 'bed', 'mattress', 'sale'],
#  ['buy', 'mattress', 'cheap'],
#  ['new', 'mattress', 'price'],
#  ['bed', 'free', 'delivery'],
#  ['discount', 'mattress', 'okc'],
#  ['best', 'time', 'buy', 'mattress', 'set'],
#  ['mattress', 'king', 'coupon'],
#  ['mattress', 'store', 'close'],
#  ['best', 'price', 'mattress'],
#  ['tucson', 'mattress', 'sale'],
#  ['mattress', 'firm', 'sale', 'flyer'],
#  ['mattress', 'near', 'location'],
#  ['chicago', 'mattress', 'outlet'],
#  ['cheap', 'brand', 'new', 'mattress'],
#  ['silver', 'dream', 'mattress'],
#  ['mattress', 'firm', 'president', 'day', 'sale'],
#  ['mattress', 'firm', 'columbus', 'ohio'],
#  ['best', 'mattress', 'sale', 'year'],
#  ['mattress', 'warehouse', 'free', 'tv'],
#  ['super', 'discount', 'mattress', 'warehouse'],
#  ['l', 'mattress'],
#  ['store', 'matress'],
#  ['cheap', 'bed', 'mattress', 'set'],
#  ['discount', 'matress', 'store'],
#  ['mattress'],
#  ['biggest', 'bed', 'sale'],
#  ['low', 'price', 'mattress', 'near'],
#  ['best', 'mattress', 'firm'],
#  ['delivery', 'mattress'],
#  ['mattress', 'warehouse', 'labor', 'day', 'sale'],
#  ['mattress', 'outlet', 'houston'],
#  ['mattress', 'one', 'day', 'delivery'],
#  ['mattress', 'discount', 'online'],
#  ['memorial', 'day', 'sale', 'mattress'],
#  ['queen', 'box', 'spring', 'dallas'],
#  ['best', 'time', 'buy', 'mattress', 'set'],
#  ['cheap', 'mattress', 'set', 'online'],
#  ['mattress', 'near', 'cheap'],
#  ['july', 'mattress', 'sale'],
#  ['portland', 'mattress', 'sale'],
#  ['best', 'mattress', 'sale', 'memorial', 'day'],
#  ['president', 'day', 'sale', 'mattress'],
#  ['mattress', 'set', 'online'],
#  ['best', 'time', 'buy', 'mattress'],
#  ['double', 'bed', 'mattress', 'deal'],
#  ['discount', 'mattress', 'baltimore'],
#  ['portland', 'mattress', 'outlet'],
#  ['best', 'mattress', 'deal', 'memorial', 'day'],
#  ['mattress', 'firm', 'ohio'],
#  ['president', 'day', 'mattress', 'sale'],
#  ['mattress', 'clearance', 'warehouse'],
#  ['buy', 'queen', 'size', 'mattress', 'online'],
#  ['bed', 'store', 'near'],
#  ['cheap', 'full', 'mattress'],
#  ['mattress', 'warehouse', 'chicago'],
#  ['mattress', 'warehouse', 'louisville'],
#  ['discount', 'mattress', 'green', 'bay'],
#  ['best', 'priced', 'mattress', 'store'],
#  ['mattress', 'king', 'warehouse'],
#  ['best', 'mattress', 'set'],
#  ['find', 'cheap', 'mattress', 'near'],
#  ['cheap', 'bed', 'mattress'],
#  ['best', 'mattress', 'delivery'],
#  ['best', 'mattress', 'store', 'chicago'],
#  ['sealy', 'factory', 'outlet'],
#  ['best', 'mattress', 'deal', 'denver'],
#  ['mattress', 'near', 'cheap'],
#  ['mattress', 'firm', 'outlet', 'store'],
#  ['macy', 'venta', 'de', 'colchones'],
#  ['mattress', 'sale', 'memorial', 'weekend'],
#  ['mattress', 'one', 'sale', 'ad'],
#  ['buy', 'mattress', 'cheap'],
#  ['discount', 'mattress'],
#  ['cheap', 'mattress', 'bed', 'set'],
#  ['mattress', 'firm', 'president', 'day', 'sale'],
#  ['cheap', 'mattress', 'sale', 'online'],
#  ['mattress', 'firm', 'open', 'today'],
#  ['mattress', 'deal', 'memorial', 'day'],
#  ['mattress', 'sale', 'president', 'day'],
#  ['dallas', 'discount', 'mattress'],
#  ['discount', 'mattress', 'portland'],
#  ['mattress', 'sale', 'memorial', 'day'],
#  ['next', 'day', 'mattress'],
#  ['mattress', 'sale', 'memorial', 'day', 'weekend'],
#  ['best', 'mattress', 'labor', 'day', 'sale'],
#  ['mattress', 'sale', 'cleveland', 'ohio'],
#  ['sealy', 'dream', 'bed'],
#  ['best', 'time', 'buy', 'mattress'],
#  ['best', 'low', 'price', 'mattress'],
#  ['name', 'brand', 'mattress'],
#  ['buy', 'bed', 'mattress', 'online'],
#  ['mattress', 'firm', 'cleveland', 'ohio'],
#  ['colchones', 'tempur', 'pedic'],
#  ['high', 'end', 'mattress', 'store'],
#  ['mattress', 'firm', 'black', 'friday'],
#  ['mattress', 'sale', 'houston', 'texas'],
#  ['cheap', 'good', 'mattress', 'set'],
#  ['mattress', 'firm', 'discount', 'center'],
#  ['memorial', 'day', 'mattress'],
#  ['mattress', 'warehouse', 'philadelphia'],
#  ['discount', 'mattress', 'store'],
#  ['find', 'mattress', 'store', 'near'],
#  ['u', 'mattress', 'sale'],
#  ['mattress', 'firm', 'memorial', 'day', 'sale'],
#  ['best', 'time', 'buy', 'mattress', 'sale'],
#  ['brand', 'new', 'mattress'],
#  ['twin', 'bargain'],
#  ['big', 'bed', 'sale'],
#  ['best', 'delivery', 'mattress'],
#  ['mattress', 'sale', 'denver', 'colorado'],
#  ['low', 'price', 'mattress', 'set'],
#  ['mattress', 'firm', 'cleveland'],
#  ['best', 'mattress', 'deal', 'memorial', 'day', 'weekend'],
#  ['best', 'mattress', 'box', 'spring', 'set'],
#  ['purple', 'mattress', 'sample'],
#  ['president', 'day', 'sale', 'mattress'],
#  ['mattress', 'dollar'],
#  ['mattress', 'sale', 'memorial', 'day'],
#  ['huge', 'bed', 'sale'],
#  ['mattress', 'firm', 'close'],
#  ['discount', 'quality', 'mattress'],
#  ['max', 'dallas'],
#  ['mattress', 'online', 'shopping'],
#  ['best', 'mattress', 'price'],
#  ['simmons', 'outlet', 'near'],
#  ['best', 'mattress', 'deal', 'online'],
#  ['mattress', 'warehouse', 'sale', 'near'],
#  ['mattress', 'firm', 'labor', 'day', 'sale'],
#  ['best', 'time', 'buy', 'mattress', 'set'],
#  ['simmons', 'mattress', 'outlet', 'dallas'],
#  ['cheap', 'good', 'bed', 'sale'],
#  ['discount', 'mattress', 'store'],
#  ['best', 'month', 'buy', 'mattress'],
#  ['discount', 'mattress', 'dallas'],
#  ['serta', 'sealy', 'mattress'],
#  ['mattress', 'warehouse', 'pittsburgh'],
#  ['discount', 'mattress', 'box', 'spring'],
#  ['mattress', 'warehouse', 'king', 'size', 'mattress'],
#  ['sealy', 'mattress', 'denver'],
#  ['best', 'time', 'year', 'buy', 'mattress'],
#  ['mattress', 'outlet', 'store', 'near'],
#  ['mattress', 'sale', 'mn'],
#  ['sealy', 'posturepedic', 'sweet', 'sleeper'],
#  ['price', 'mattress'],
#  ['discount', 'mattress', 'tucson'],
#  ['fourth', 'july', 'mattress', 'sale'],
#  ['best', 'buy', 'mattress'],
#  ['bedroom', 'mattress', 'set'],
#  ['mattress', 'warehouse', 'sale'],
#  ['best', 'mattress', 'shop'],
#  ['today', 'show', 'mattress'],
#  ['mattress', 'delivery', 'denver'],
#  ['discount', 'mattress', 'pittsburgh'],
#  ['mattress', 'warehouse', 'columbus'],
#  ['mattress'],
#  ['buy', 'affordable', 'mattress'],
#  ['best', 'mattress', 'price'],
#  ['best', 'time', 'buy', 'mattress'],
#  ['great', 'mattress', 'cheap'],
#  ['best', 'premium', 'mattress'],
#  ['full', 'mattress', 'cheap'],
#  ['mattress', 'mattress'],
#  ['best', 'mattress', 'la', 'vega'],
#  ['macys', 'bedding', 'deal'],
#  ['mattress', 'bed', 'set'],
#  ['buy', 'cheap', 'mattress', 'online'],
#  ['best', 'time', 'buy', 'mattress', 'sale'],
#  ['mattress', 'outlet', 'denver'],
#  ['mattress', 'outlet', 'portland'],
#  ['mattress', 'firm', 'pillow', 'coupon'],
#  ['mattress', 'warehouse', 'houston'],
#  ['mattress', 'coupon'],
#  ['price', 'mattress'],
#  ['buy', 'mattress', 'cheap'],
#  ['mattress', 'warehouse', 'portland'],
#  ['macy', 'minimum', 'wage'],
#  ['cheapest', 'best', 'mattress'],
#  ['inch', 'mattress'],
#  ['mattress', 'firm', 'deliver'],
#  ['online', 'mattress', 'outlet'],
#  ['discount', 'mattress', 'box', 'spring'],
#  ['free', 'adjustable', 'base', 'mattress', 'firm'],
#  ['sealy', 'sweet', 'sleeper', 'mattress'],
#  ['best', 'price', 'mattress'],
#  ['sealy', 'serta', 'mattress'],
#  ['buy', 'good', 'mattress', 'cheap'],
#  ['matress', 'store', 'near'],
#  ['best', 'mattress', 'set'],
#  ['platinum', 'dream', 'mattress'],
#  ['mattress', 'firm', 'murfreesboro'],
#  ['buy', 'good', 'mattress', 'cheap'],
#  ['furniture', 'mattress', 'warehouse', 'san', 'diego'],
#  ['mattress', 'sale', 'cleveland', 'ohio'],
#  ['mattress', 'firm', 'clearance', 'center', 'location'],
#  ['mattress', 'firm', 'portland', 'tx'],
#  ['buying', 'bed', 'mattress'],
#  ['single', 'mattress', 'sale'],
#  ['single', 'mattress', 'sale'],
#  ['best', 'bed', 'delivery'],
#  ['best', 'mattress', 'store', 'chicago'],
#  ['cheap', 'mattress', 'sale'],
#  ['sealy', 'posturepedic', 'v', 'serta', 'perfect', 'sleeper'],
#  ['serta', 'sealy'],
#  ['mattress', 'store', 'near', 'cheap'],
#  ['foam', 'mattress', 'discount'],
#  ['mattress', 'firm', 'furniture'],
#  ['best', 'month', 'buy', 'mattress'],
#  ['futon', 'mattress', 'tulsa'],
#  ['mattress', 'warehouse', 'baltimore'],
#  ['discount', 'mattress', 'jacksonville', 'fl'],
#  ['sealy', 'serta', 'mattress', 'best'],
#  ['cheap', 'bed', 'mattress'],
#  ['mattress', 'firm', 'outlet', 'houston'],
#  ['mattress', 'store', 'murfreesboro'],
#  ['cheap', 'mattress', 'delivery'],
#  ['sleep', 'mattress', 'near'],
#  ['single', 'mattress', 'best', 'price'],
#  ['bed', 'free', 'mattress'],
#  ['foam', 'mattress', 'outlet'],
#  ['best', 'time', 'buy', 'tempurpedic', 'mattress'],
#  ['best', 'mattress', 'price'],
#  ['free', 'delivery', 'mattress', 'warehouse'],
#  ['cheap', 'top', 'mattress'],
#  ...]

# %%
# convert token to sentence
sent_keywords = list()
def token_to_sent(tokenized_keywords):
    for token_keywords in tokenized_keywords:
        sent_keywords.append(' '.join(token_keywords))
    return sent_keywords

# %%
sentence_keywords = token_to_sent(cleaned_keywords)

# %%
sentence_keywords
# Out:
# ['mattress sale',
#  'mattress sale',
#  'mattress deal',
#  'mattress sale near',
#  'macys mattress sale',
#  'mattress sale',
#  'macy mattress sale',
#  'mattress sale',
#  'mattress sale near',
#  'macys mattress',
#  'matress sale',
#  'mattress sale',
#  'mattress sale near',
#  'macys mattress',
#  'macy mattress sale',
#  'matress sale',
#  'mattress sale near',
#  'mattress sale',
#  'sale mattress',
#  'mattress sale weekend',
#  'sale mattress',
#  'sale mattress',
#  'macy mattress',
#  'best mattress deal',
#  'macys mattress sale date',
#  'mattress sale near',
#  'macys matress sale',
#  'mattress deal near',
#  'mattress sale macy',
#  'macys mattress sale',
#  'macy mattress',
#  'mattress sale today',
#  'mattress sale macys',
#  'bed mattress deal',
#  'macy mattress',
#  'macy mattress sale coupon',
#  'macy mattress sale',
#  'bed mattress sale',
#  'bed mattress sale',
#  'macy matress sale',
#  'mattress sale today',
#  'macy labor day mattress sale',
#  'best mattress sale today',
#  'mattress deal',
#  'mattress macy',
#  'matress sale',
#  'buy mattress near',
#  'mattres sale',
#  'sale mattress',
#  'best deal mattress',
#  'mattress clearance sale',
#  'macys furniture mattress',
#  'matress deal',
#  'mattress special',
#  'macys matress',
#  'macys mattress sale',
#  'single mattress sale',
#  'bed mattress sale',
#  'best matress deal',
#  'best mattress deal near',
#  'macy mattress sale',
#  'macy mattress sale date',
#  'macy mattress clearance',
#  'mattress sale near',
#  'macy columbus day mattress sale',
#  'macy mattress sale',
#  'deal mattress',
#  'mattress sale nyc',
#  'macy furniture mattress sale',
#  'macys mattress sale',
#  'macy mattress sale',
#  'best deal mattress',
#  'macy one day mattress sale',
#  'macys furniture mattress',
#  'macy july mattress sale',
#  'new mattress sale',
#  'sale mattress',
#  'mattress sale area',
#  'macys matresses',
#  'bed sale near',
#  'macys mattress sale',
#  'buy mattress',
#  'mattress sale macys',
#  'mattress sale weekend',
#  'macy mattress sale today',
#  'macys mattress store',
#  'matress sale near',
#  'best mattress sale',
#  'macy mattress',
#  'macy mattress outlet',
#  'sale mattress',
#  'macy bed mattress sale',
#  'veteran day mattress sale',
#  'mattresssale',
#  'matresses sale',
#  'mattress sale',
#  'matresses sale',
#  'mattress macys',
#  'sleep train mattress sale',
#  'matress sale near',
#  'deal mattress near',
#  'christmas mattress sale',
#  'mattress',
#  'macy memorial day mattress sale',
#  'macy bed mattress',
#  'mattress store sale',
#  'best mattress sale',
#  'mattress sell',
#  'mattress special near',
#  'best mattress sale weekend',
#  'mattress store sale',
#  'buy mattress near',
#  'mattress discount near',
#  'sale mattress',
#  'macy matress',
#  'veteran day mattress sale',
#  'macys mattress full',
#  'bed mattress sale near',
#  'best time buy mattress macy',
#  'memorial day mattress sale',
#  'discount mattress set',
#  'macys mattress store',
#  'bed mattress sale near',
#  'best mattress sale today',
#  'macys com mattress sale',
#  'matte sale',
#  'end year mattress sale',
#  'macy bed sale',
#  'macy veteran day mattress sale',
#  'matress sale',
#  'macy black friday mattress sale',
#  'macys com mattress',
#  'buy mattress near',
#  'mattress best deal',
#  'place sell mattress near',
#  'mattress set sale near',
#  'columbus day mattress sale',
#  'best mattress deal',
#  'great mattress deal',
#  'mattres mattres',
#  'mattress sell',
#  'bed mattress sale',
#  'best deal mattress',
#  'firm mattress sale',
#  'best deal mattress near',
#  'buy mattress near',
#  'best mattress sale weekend',
#  'mattress macy',
#  'best mattress deal today',
#  'mattress set deal',
#  'bed special',
#  'macy mattress outlet',
#  'mattress sale',
#  'mattress macys sale',
#  'mattress sale week',
#  'mattress sale today',
#  'bed sale weekend',
#  'sale bed mattress',
#  'best deal bed mattress',
#  'macy mattress sale',
#  'memorial day mattress sale',
#  'mattress macys',
#  'macys bed sale',
#  'best mattress sale near',
#  'store sell mattress near',
#  'mattress sale near location',
#  'bed sale near',
#  'mattress deal today',
#  'sale mattress near',
#  'current mattress sale',
#  'bed mattress sale',
#  'bed mattress sale',
#  'mattress sale area',
#  'macy queen mattress',
#  'mattress store sale',
#  'bed mattress sale',
#  'good deal mattress',
#  'macy mattress sale queen',
#  'mattress sale',
#  'best mattress price near',
#  'christmas mattress sale',
#  'bed mattress sale',
#  'best deal mattress',
#  'mattres sale',
#  'macy mattress sale full size',
#  'bed mattress deal',
#  'affordable mattress near',
#  'bed matress sale',
#  'macy venta de colchones',
#  'mattress mattress',
#  'bed mattress sale',
#  'mattress sale free delivery',
#  'mattress free delivery',
#  'mattress firm veteran day sale',
#  'macy president day mattress sale',
#  'macy mattress department',
#  'mattress bed sale',
#  'mattress macy',
#  'top mattress deal',
#  'macy full size mattress',
#  'discount mattress near',
#  'mattress sale veteran day',
#  'single bed mattress sale',
#  'sell mattress',
#  'mattress bed sale',
#  'mattress firm sale weekend',
#  'sale mattress',
#  'best mattress sale',
#  'new mattress sale',
#  'macy mattress sale king size',
#  'best deal mattress',
#  'mattress sa',
#  'double bed mattress sale',
#  'macys mattress sale',
#  'macy mattress black friday sale',
#  'macy mattress store',
#  'macy mattress queen',
#  'good mattress sale',
#  'mattress firm mattress sale',
#  'foam mattress sale',
#  'macy bed sale',
#  'mattress free shipping',
#  'macy twin mattress sale',
#  'mattress firm special',
#  'looking mattress sale',
#  'bed deal near',
#  'mattress sale free delivery',
#  'cheapest mattress near',
#  'best price mattress near',
#  'columbus day mattress sale',
#  'matress deal',
#  'mismatch mattress sale',
#  'best price mattress',
#  'good mattress deal',
#  'mattress clearance near',
#  'mattress sale free shipping',
#  'new mattress near',
#  'macys mattress outlet',
#  'macy mattress set sale',
#  'closeout mattress sale',
#  'king mattress sale near',
#  'new year mattress sale',
#  'cheap mattress sale',
#  'bed mattress deal',
#  'macy mattress set',
#  'best mattress sale',
#  'queen mattress macys',
#  'mattress discount store near',
#  'bed mattress sale',
#  'mattress firm mattress sale',
#  'bed mattress sale',
#  'mattress store near',
#  'sale bed mattress',
#  'mattress',
#  'best mattress sale',
#  'mattress macys',
#  'matteress sale',
#  'buy mattress near',
#  'best sale mattress',
#  'matresses near',
#  'bed mattress sale',
#  'best deal mattress set',
#  'firm mattress near',
#  'easter mattress sale',
#  'macy mattress sale',
#  'mattress sale around',
#  'labor day mattress sale',
#  'mattress firm clearance near',
#  'big mattress sale',
#  'mattress department',
#  'bed sale today',
#  'mattress outlet near',
#  'best deal mattress',
#  'venta de colchones en macy',
#  'discount mattress sale',
#  'new mattress sale',
#  'macy bed mattress',
#  'macys mattress queen',
#  'new year mattress sale',
#  'bed mattress sale',
#  'mattress sale',
#  'sale mattress',
#  'sale bed mattress',
#  'best price matresses',
#  'mattress sale denver',
#  'cheap bed mattress included',
#  'macys mattress twin',
#  'cheap mattress near',
#  'president day mattress sale',
#  'bed sale nyc',
#  'mattress king tulsa',
#  'matress near',
#  'foam mattress near',
#  'special mattress',
#  'macy mattress store locator',
#  'mattress sale portland',
#  'new mattress sale cheap',
#  'mattress store free delivery',
#  'mattress sale memorial day',
#  'top mattress sale',
#  'biggest mattress sale',
#  'macy mattress',
#  'best mattress sale',
#  'macys mattress set',
#  'upcoming mattress sale',
#  'deal mattress',
#  'bed mattress near',
#  'queen mattress clearance free shipping',
#  'brand new mattress sale',
#  'macys mattress queen',
#  'full size mattress sale near',
#  'memorial day mattress sale',
#  'mattress today',
#  'mattress store near',
#  'mattress sale going',
#  'mattress clearance store',
#  'best mattress deal weekend',
#  'mattress discount store near',
#  'memorial day mattress sale near',
#  'cheap mattress sale',
#  'king mattress clearance sale',
#  'cheap mattress set near',
#  'mattress firm semi annual sale',
#  'bed mattress sale',
#  'queen mattress set sale free shipping',
#  'mattress lowest price',
#  'show mattress',
#  'new year mattress sale',
#  'mattress sale',
#  'mattress sale price',
#  'cheapest mattress near',
#  'mattress firm clearance store',
#  'columbus day mattress sale',
#  'next mattress',
#  'macy mattress clearance',
#  'free delivery mattress',
#  'bed mattress set sale',
#  'mother day mattress sale',
#  'mattress discount store',
#  'full mattress sale free shipping',
#  'find mattress sale',
#  'mismatched mattress sale',
#  'mattress sale online',
#  'mismatched mattress set',
#  'day mattress',
#  'mattress sale online',
#  'mattress store around',
#  'cheap mattress store near',
#  'macy queen mattress set sale',
#  'macys full size mattress',
#  'mattress base sale',
#  'mattress sale memorial day',
#  'buy mattress near',
#  'mattress store near',
#  'bed mattress deal',
#  'mattress clearance houston',
#  'mattress sale',
#  'mattress clearance outlet',
#  'holiday mattress sale',
#  'bed mattress deal',
#  'best place buy mattress near',
#  'mattress sale pa',
#  'mattress one veteran day sale',
#  'labor day mattress sale',
#  'cheap bed mattress sale',
#  'memorial mattress sale',
#  'mattress clearance usa',
#  'store sell mattress',
#  'queen size mattress macys',
#  'memorial day mattress sale',
#  'looking mattress',
#  'mattress veteran day sale',
#  'queen mattress set mattress firm',
#  'bed mattress set sale',
#  'memorial day mattress sale',
#  'firm bed sale',
#  'best price mattress',
#  'mattress buy',
#  'mattress sale houston',
#  'best price mattress',
#  'mattress sale cheap',
#  'firm mattress deal',
#  'mattress online free shipping',
#  'mattress sale memorial day',
#  'mismatch mattress',
#  'mattress sale labor day',
#  'best matress sale',
#  'place sell mattress',
#  'holiday mattress sale',
#  'bed sale mattress',
#  'mattress',
#  'mattress sale',
#  'discount mattress store near',
#  'mattress store sale',
#  'good deal bed mattress',
#  'bed sale free delivery',
#  'bed mattress sale cheap',
#  'low price mattress sale',
#  'cheap bed mattress deal',
#  'discount mattress set near',
#  'mattress sale',
#  'cheapest mattress store near',
#  'memorial day matress sale',
#  'mattress tv deal',
#  'mattress delivery near',
#  'mattress free delivery',
#  'discount bed mattress',
#  'shop mattress near',
#  'discounted mattress',
#  'mattress sale online',
#  'memorial day sale mattress',
#  'buy mattress near',
#  'buy cheap mattress near',
#  'discounted mattress',
#  'macys mattress king',
#  'veteran day sale mattress',
#  'mattress firm year end sale',
#  'best mattress store near',
#  'mattress online free shipping',
#  'veteran day sale mattress',
#  'queen mattress set free delivery',
#  'good deal mattress',
#  'mattress sale near',
#  'cheapest mattress price',
#  'mattress sale online free delivery',
#  'macy mattress queen',
#  'mattress firm closeout',
#  'macy queen mattress',
#  'mattress sale okc',
#  'mattress firm clearance center houston',
#  'mattress bed sale',
#  'best mattress near',
#  'mattress sale nearby',
#  'best price mattress set',
#  'cheap new mattress near',
#  'mattress doorbuster',
#  'mattress',
#  'discount mattress near',
#  'houston discount mattress',
#  'mattress sale free tv',
#  'mattress place near',
#  'buy cheap mattress',
#  'mattress set free delivery',
#  'cheap bed mattress sale',
#  'w mattress sale',
#  'mattress set free delivery',
#  'queen mattress sale free delivery',
#  'mattress sale online',
#  'cheap mattress online free shipping',
#  'bed mattress near',
#  'discounted mattress near',
#  'mattress firm columbus day sale',
#  'free shipping mattress',
#  'cheap bed mattress sale',
#  'bed plus mattress sale',
#  'best price mattress',
#  'king mattress near',
#  'quality mattress sale',
#  'cheapest mattress sale',
#  'mattress sale online',
#  'memorial day sale mattress',
#  'cheap mattress free delivery',
#  'cheap bed mattress set',
#  'mattress sale columbus day',
#  'mattress',
#  'mattress sale mn',
#  'discount mattress free shipping',
#  'bed mattress included sale',
#  'cheap bed sale mattress',
#  'low cost mattress set',
#  'twin mattress set mattress firm',
#  'discount bed mattress',
#  'free tv mattress purchase',
#  'mattress free shipping',
#  'get best deal mattress',
#  'mattress memorial day sale',
#  'mattress firm memorial day sale',
#  'clearance mattress box spring',
#  'mattress sale cheap',
#  'cheap name brand mattress',
#  'mattress online sale',
#  'best price mattress',
#  'buy mattress online free shipping',
#  'discount mattress online free delivery',
#  'president sale mattress',
#  'bed mattress deal',
#  'bed mattress sale',
#  'cheap mattress deal',
#  'labor day mattress sale',
#  'mattress firm labor day sale',
#  'cheap bed mattress sale',
#  'buy mattress set',
#  'mattress offer online',
#  'new mattress set',
#  'mattress labor day sale',
#  'sell bed mattress',
#  'cheap bed mattress set',
#  'mattress sale',
#  'bed matress set',
#  'veteran day bed sale',
#  'macys sa',
#  'best mattress offer',
#  'memorial day matress sale',
#  'mattress king memorial day sale',
#  'buy mattress cheap',
#  'best sale mattress',
#  'google mattress',
#  'mismatched mattress',
#  'mattress sale houston tx',
#  'columbus day bed sale',
#  'queen mattress set free shipping',
#  'best memorial day mattress sale',
#  'bed deal',
#  'cheapest place buy mattress set',
#  'best bed sale',
#  'cheap mattress free shipping',
#  'cheap mattress set',
#  'bed mattress set cheap',
#  'best price mattress set',
#  'mattress nearby',
#  'discount mattress online',
#  'best price mattress',
#  'full mattress free shipping',
#  'mattress sale cleveland ohio',
#  'premium mattress outlet',
#  'matress firm near',
#  'get best mattress deal',
#  'looking mattress',
#  'online mattress deal',
#  'full size mattress set free delivery',
#  'tss warehouse coupon',
#  'mattress outlet online',
#  'price mattress',
#  'president day mattress sale',
#  'free mattress delivery',
#  'cheap double mattress sale',
#  'labor day mattress sale',
#  'mattress clearance chicago',
#  'denver discount mattress',
#  'low price mattress',
#  'discount mattress online',
#  'sell cheapest mattress',
#  'mattress sale cheap',
#  'buy mattress cheap',
#  'buy discount mattress',
#  'july mattress sale',
#  'best buy closeout',
#  'mattress sale cheap price',
#  'bed mattress set',
#  'new bed mattress price',
#  'purchase mattress near',
#  'day mattress',
#  'cheap full mattress near',
#  'mattress sale dfw',
#  'cheapest mattress',
#  'cheap new mattress boxspring set',
#  'memorial day sale mattress',
#  'mattress delivery seattle',
#  'best place buy mattress near',
#  'cheapest bed mattress',
#  'best price mattress',
#  'mattress firm sale ad',
#  'cheap mattress near',
#  'macy bed sale',
#  'mattres',
#  'best price mattress',
#  'cheapest mattress store',
#  'cheapest bed sale',
#  'lowest price mattress',
#  'mattress firm clearance outlet',
#  'tempurpedic mattress closeout sale',
#  'king size mattress free shipping',
#  'cheapest full mattress',
#  'memory foam mattress sale near',
#  'biggest mattress sale year',
#  'mattress warehouse president day sale',
#  'mattress outlet seattle',
#  'buy mattress cheap',
#  'mattress deal online',
#  'warehouse clearance mattress',
#  'mattress around',
#  'premium mattress outlet inc',
#  'mattress firm doorbuster',
#  'mattress warehouse nyc',
#  'mattress base sale',
#  'discount boxspring',
#  'mattress warehouse mattress sale',
#  'best deal mattress furniture',
#  'twin mattress okc',
#  'buy cheap bed mattress',
#  'mattress firm clearance',
#  'best mattress store near',
#  'mattress clearance dallas',
#  'buy cheap mattress near',
#  'mattress firm memorial day sale',
#  'discount mattress boxspring set',
#  'cheap bed mattress deal',
#  'mattress firm doorbuster sale',
#  'denver mattress president day sale',
#  'sell mattress cheap',
#  'matteress',
#  'mattress sale',
#  'mattress sale denver',
#  'cheapest mattress',
#  'mattress warehouse tucson',
#  'denver mattress memorial day sale',
#  'memorial weekend mattress sale',
#  'mattress sale online free shipping',
#  'mattress firm labor day sale',
#  'twin mattress sale houston',
#  'memory foam mattress free shipping',
#  'cheapest place buy mattress box spring',
#  'mattress warehouse sale',
#  'full mattress free delivery',
#  'online mattress sale',
#  'mattressnow',
#  'cheap bed seattle',
#  'cheap new bed near',
#  'mattress store',
#  'buy cheap mattress',
#  'macys sale today',
#  'discount mattress baltimore',
#  'cheap bed mattress deal',
#  'cheap new mattress set',
#  'mattress firm back school sale',
#  'bed sale houston',
#  'cheapest place buy mattress set',
#  'mattress firm king size mattress price',
#  'mattress discount store',
#  'best place buy mattress near',
#  'bed mattress cheap',
#  'cheapest full mattress set',
#  'affordable mattress nyc',
#  'memorial day sale mattress',
#  'mattress warehouse san antonio',
#  'mattress sale',
#  'mattress sale denver co',
#  'firm mattress discount',
#  'mattress store near deliver',
#  'cheapest bed mattress',
#  'mattress store',
#  'mattress online free delivery',
#  'full size bed delivery',
#  'denver mattress labor day sale',
#  'sleep train president day sale',
#  'serta president day sale',
#  'single mattress sale',
#  'foam mattress clearance',
#  'best mattress sale',
#  'discount mattress firm',
#  'best place buy mattress',
#  'cheap mattress sale near',
#  'mattress warehouse clearance outlet',
#  'mattress firm memorial day sale',
#  'cheap discount mattress',
#  'discount mattress okc',
#  'mattress firm president sale',
#  'bed mattress cheap',
#  'cheapest bed mattress',
#  'queen mattress store',
#  'best place buy mattress set',
#  'bed mattress set deal',
#  'new mattress set',
#  'free mattress near',
#  'mattress sale okc',
#  'sleep train mattress sale',
#  'buy bed mattress',
#  'mattress firm july sale',
#  'mattress cheap price',
#  'mattress king tulsa hill',
#  'online mattress store free delivery',
#  'mattress sale cleveland',
#  'sleepy mattress deal',
#  'tucson mattress sale',
#  'super single mattress sale',
#  'cheapest place mattress',
#  'la vega mattress outlet',
#  'mattress sale portland',
#  'mattress firm clearance houston tx',
#  'memory foam near',
#  'mattress sale',
#  'best price mattress set',
#  'cheap bed mattress set',
#  'houston mattress sale',
#  'mattress firm deal',
#  'best price mattress',
#  'queen box spring sale near',
#  'buy mattress cheap',
#  'bed mattress set',
#  'mattress warehouse black friday sale',
#  'best price mattress box spring',
#  'small mattress sale',
#  'buy cheap mattress online free shipping',
#  'mattress sale denver',
#  'single mattress near',
#  'labor day sale mattress',
#  'best buy mattress',
#  'mattress one sale',
#  'cheap queen mattress set near',
#  'best price mattress set',
#  'best mattress queen',
#  'mattress firm july sale',
#  'leesa mattress nyc',
#  'mattress firm clearance center san antonio',
#  'sealy futon',
#  'macy foam mattress',
#  'cheap bed mattress sale',
#  'discount mattress houston',
#  'top mattress store',
#  'mattress king',
#  'mattress queen',
#  'buy mattress set online',
#  'mattress sale memorial day',
#  'sealy mattress warehouse',
#  'macys bedding sale',
#  'mattress close',
#  'mattress king chicago',
#  'discount mattress tulsa',
#  'mattress warehouse houston tx',
#  'king size mattress set',
#  'buy mattress cheap',
#  'cheap mattress area',
#  'mattress firm fourth july sale',
#  'mattress firm louisville',
#  'best labor day mattress sale',
#  'mattress one memorial day sale',
#  'mattress firm columbus',
#  'best mattress set',
#  'buy cheap mattress set',
#  'serta mattress warehouse',
#  'cheap bed mattress deal',
#  'best buy mattress sale',
#  'discount mattress la vega',
#  'july mattress sale',
#  'inexpensive mattress near',
#  'mattress firm near',
#  'foam mattress discount',
#  'cheap bed matress deal',
#  'mattress warehouse san diego',
#  'cheap single mattress sale',
#  'looking cheap mattress',
#  'best price matress',
#  'mattress sale labor day',
#  'futon nyc free delivery',
#  'mattress sale jacksonville',
#  'bed mattress set',
#  'sealy futon collection',
#  'full mattress delivery',
#  'discount mattress denver',
#  'cheap mattress set cleveland ohio',
#  'brand new mattress cheap',
#  'okc mattress sale',
#  'biggest mattress',
#  'mattress firm sale ad',
#  'full mattress online',
#  'best price mattress',
#  'mattress one clearance',
#  'bed mattress cheap',
#  'memorial day sale mattress',
#  'cheap mattress firm',
#  'labor day mattress sale',
#  'queen mattress set',
#  'u mattress memorial day sale',
#  'mattress firm clearance jacksonville fl',
#  'foam mattress store near',
#  'cheapest place buy mattress set',
#  'best priced mattress',
#  'memorial day mattress sale',
#  'cheapest mattress',
#  'best time buy mattress box spring',
#  'president day sale mattress',
#  'buy cheap mattress near',
#  'queen mattress online',
#  'memorial day weekend mattress sale',
#  'houston discount mattress',
#  'inexpensive mattress sale',
#  'futon mattress dollar',
#  'cheap bed mattress sale',
#  'buy mattress cheap',
#  'new mattress price',
#  'bed free delivery',
#  'discount mattress okc',
#  'best time buy mattress set',
#  'mattress king coupon',
#  'mattress store close',
#  'best price mattress',
#  'tucson mattress sale',
#  'mattress firm sale flyer',
#  'mattress near location',
#  'chicago mattress outlet',
#  'cheap brand new mattress',
#  'silver dream mattress',
#  'mattress firm president day sale',
#  'mattress firm columbus ohio',
#  'best mattress sale year',
#  'mattress warehouse free tv',
#  'super discount mattress warehouse',
#  'l mattress',
#  'store matress',
#  'cheap bed mattress set',
#  'discount matress store',
#  'mattress',
#  'biggest bed sale',
#  'low price mattress near',
#  'best mattress firm',
#  'delivery mattress',
#  'mattress warehouse labor day sale',
#  'mattress outlet houston',
#  'mattress one day delivery',
#  'mattress discount online',
#  'memorial day sale mattress',
#  'queen box spring dallas',
#  'best time buy mattress set',
#  'cheap mattress set online',
#  'mattress near cheap',
#  'july mattress sale',
#  'portland mattress sale',
#  'best mattress sale memorial day',
#  'president day sale mattress',
#  'mattress set online',
#  'best time buy mattress',
#  'double bed mattress deal',
#  'discount mattress baltimore',
#  'portland mattress outlet',
#  'best mattress deal memorial day',
#  'mattress firm ohio',
#  'president day mattress sale',
#  'mattress clearance warehouse',
#  'buy queen size mattress online',
#  'bed store near',
#  'cheap full mattress',
#  'mattress warehouse chicago',
#  'mattress warehouse louisville',
#  'discount mattress green bay',
#  'best priced mattress store',
#  'mattress king warehouse',
#  'best mattress set',
#  'find cheap mattress near',
#  'cheap bed mattress',
#  'best mattress delivery',
#  'best mattress store chicago',
#  'sealy factory outlet',
#  'best mattress deal denver',
#  'mattress near cheap',
#  'mattress firm outlet store',
#  'macy venta de colchones',
#  'mattress sale memorial weekend',
#  'mattress one sale ad',
#  'buy mattress cheap',
#  'discount mattress',
#  'cheap mattress bed set',
#  'mattress firm president day sale',
#  'cheap mattress sale online',
#  'mattress firm open today',
#  'mattress deal memorial day',
#  'mattress sale president day',
#  'dallas discount mattress',
#  'discount mattress portland',
#  'mattress sale memorial day',
#  'next day mattress',
#  'mattress sale memorial day weekend',
#  'best mattress labor day sale',
#  'mattress sale cleveland ohio',
#  'sealy dream bed',
#  'best time buy mattress',
#  'best low price mattress',
#  'name brand mattress',
#  'buy bed mattress online',
#  'mattress firm cleveland ohio',
#  'colchones tempur pedic',
#  'high end mattress store',
#  'mattress firm black friday',
#  'mattress sale houston texas',
#  'cheap good mattress set',
#  'mattress firm discount center',
#  'memorial day mattress',
#  'mattress warehouse philadelphia',
#  'discount mattress store',
#  'find mattress store near',
#  'u mattress sale',
#  'mattress firm memorial day sale',
#  'best time buy mattress sale',
#  'brand new mattress',
#  'twin bargain',
#  'big bed sale',
#  'best delivery mattress',
#  'mattress sale denver colorado',
#  'low price mattress set',
#  'mattress firm cleveland',
#  'best mattress deal memorial day weekend',
#  'best mattress box spring set',
#  'purple mattress sample',
#  'president day sale mattress',
#  'mattress dollar',
#  'mattress sale memorial day',
#  'huge bed sale',
#  'mattress firm close',
#  'discount quality mattress',
#  'max dallas',
#  'mattress online shopping',
#  'best mattress price',
#  'simmons outlet near',
#  'best mattress deal online',
#  'mattress warehouse sale near',
#  'mattress firm labor day sale',
#  'best time buy mattress set',
#  'simmons mattress outlet dallas',
#  'cheap good bed sale',
#  'discount mattress store',
#  'best month buy mattress',
#  'discount mattress dallas',
#  'serta sealy mattress',
#  'mattress warehouse pittsburgh',
#  'discount mattress box spring',
#  'mattress warehouse king size mattress',
#  'sealy mattress denver',
#  'best time year buy mattress',
#  'mattress outlet store near',
#  'mattress sale mn',
#  'sealy posturepedic sweet sleeper',
#  'price mattress',
#  'discount mattress tucson',
#  'fourth july mattress sale',
#  'best buy mattress',
#  'bedroom mattress set',
#  'mattress warehouse sale',
#  'best mattress shop',
#  'today show mattress',
#  'mattress delivery denver',
#  'discount mattress pittsburgh',
#  'mattress warehouse columbus',
#  'mattress',
#  'buy affordable mattress',
#  'best mattress price',
#  'best time buy mattress',
#  'great mattress cheap',
#  'best premium mattress',
#  'full mattress cheap',
#  'mattress mattress',
#  'best mattress la vega',
#  'macys bedding deal',
#  'mattress bed set',
#  'buy cheap mattress online',
#  'best time buy mattress sale',
#  'mattress outlet denver',
#  'mattress outlet portland',
#  'mattress firm pillow coupon',
#  'mattress warehouse houston',
#  'mattress coupon',
#  'price mattress',
#  'buy mattress cheap',
#  'mattress warehouse portland',
#  'macy minimum wage',
#  'cheapest best mattress',
#  'inch mattress',
#  'mattress firm deliver',
#  'online mattress outlet',
#  'discount mattress box spring',
#  'free adjustable base mattress firm',
#  'sealy sweet sleeper mattress',
#  'best price mattress',
#  'sealy serta mattress',
#  'buy good mattress cheap',
#  'matress store near',
#  'best mattress set',
#  'platinum dream mattress',
#  'mattress firm murfreesboro',
#  'buy good mattress cheap',
#  'furniture mattress warehouse san diego',
#  'mattress sale cleveland ohio',
#  'mattress firm clearance center location',
#  'mattress firm portland tx',
#  'buying bed mattress',
#  'single mattress sale',
#  'single mattress sale',
#  'best bed delivery',
#  'best mattress store chicago',
#  'cheap mattress sale',
#  'sealy posturepedic v serta perfect sleeper',
#  'serta sealy',
#  'mattress store near cheap',
#  'foam mattress discount',
#  'mattress firm furniture',
#  'best month buy mattress',
#  'futon mattress tulsa',
#  'mattress warehouse baltimore',
#  'discount mattress jacksonville fl',
#  'sealy serta mattress best',
#  'cheap bed mattress',
#  'mattress firm outlet houston',
#  'mattress store murfreesboro',
#  'cheap mattress delivery',
#  'sleep mattress near',
#  'single mattress best price',
#  'bed free mattress',
#  'foam mattress outlet',
#  'best time buy tempurpedic mattress',
#  'best mattress price',
#  'free delivery mattress warehouse',
#  'cheap top mattress',
#  ...]

# %%
# distinct keywords
distinct_keywords = list(set(sentence_keywords))

# %%
distinct_keywords
# Out:
# ['mattress firm cyber monday',
#  'mattress online sale',
#  'macys bedding deal',
#  'costco mattress full size',
#  'new mattress sale cheap',
#  'sleep mattress near',
#  'best mattress store near',
#  'mattress firm la vega',
#  'california twin mattress',
#  'mattress one sale ad',
#  'doctor choice firm mattress',
#  'buy good cheap mattress',
#  'denver mattress pillow top',
#  'price bed mattress',
#  'buy cheap mattress online',
#  'queen king mattress',
#  'mattress sale free shipping',
#  'furniture mattress discount king',
#  'macys mattress store',
#  'cheap new mattress set',
#  'twin mattress set mattress firm',
#  'mattress firm close',
#  'sleep country mattress sale',
#  'best time buy matress',
#  'three quarter bed mattress box spring',
#  'buy mattress',
#  'matresses sale',
#  'sleep train mattress sale',
#  'quality mattress discount price',
#  'king mattress near',
#  'futon mattress san antonio',
#  'mattress firm semi annual sale',
#  'mattress king chicago',
#  'mattress store online',
#  'best deal mattress furniture',
#  'best buy memory foam mattress',
#  'new firm mattress',
#  'matress sale',
#  'cheapest mattress store near',
#  'discount mattress jacksonville fl',
#  'macy mattress black friday sale',
#  'mattress furniture super center',
#  'new mattress online',
#  'u mattress black friday deal',
#  'discount mattress dallas tx',
#  'futon mattress stlouis',
#  'foam mattress online',
#  'good quality mattress low price',
#  'low price mattress',
#  'furniture mattress warehouse san diego',
#  'mismatch mattress',
#  'top mattress sale',
#  'best mattress la vega',
#  'mattress cheap price',
#  'denver mattress coupon',
#  'mattress warehouse sale near',
#  'doctor choice plush mattress review',
#  'discount mattress location',
#  'top rated plush mattress',
#  'foam mattress outlet',
#  'discount mattress baltimore',
#  'mattress firm oklahoma city',
#  'macy foam mattress',
#  'bed deal near',
#  'brand new mattress',
#  'mattress firm jacksonville',
#  'sleep source mattress',
#  'mattress store',
#  'tss warehouse coupon',
#  'queen mattress set mattress firm',
#  'mattress firm columbus',
#  'mattress labor day sale',
#  'fourth july mattress sale',
#  'looking cheap mattress',
#  'high end mattress store',
#  'mattress firm veteran day sale',
#  'deal mattress near',
#  'twin mattress sale houston',
#  'cheap mattress sale online',
#  'matteress',
#  'matteress sale',
#  'best labor day mattress sale',
#  'denver mattress doctor choice euro top',
#  'mattress deal denver',
#  'mattress sale denver colorado',
#  'quarter mattress',
#  'discount mattress green bay',
#  'best bed sale',
#  'sealy posturepedic sweet sleeper',
#  'mattress place around',
#  'mattress firm clearance center san antonio',
#  'denver mattress doctor choice firm',
#  'mattress firm open today',
#  'mattress free',
#  'best deal mattress near',
#  'cheap bed mattress deal',
#  'mattress sale online free delivery',
#  'firm mattress discount',
#  'mattress firm discount',
#  'place sell cheap mattress',
#  'best buy mattress',
#  'bedroom mattress set',
#  'patriot day mail delivery',
#  'mattress shopping online',
#  'mattress firm ohio',
#  'mattress firm furniture',
#  'nearest mattress store',
#  'macy bed sale',
#  'best place buy mattress set',
#  'old mattress sale',
#  'mattress sale today',
#  'queen box spring sale near',
#  'coupon mattress firm',
#  'mattress murfreesboro',
#  'mattress king tulsa hill',
#  'futon mattress la vega',
#  'much cheap mattress',
#  'garage sale mattress',
#  'mattress discount store near',
#  'macys mattress sale date',
#  'sell mattress online',
#  'get best mattress deal',
#  'simmons bedding company dallas tx',
#  'mattress store near deliver',
#  'mattress firm online coupon',
#  'mattress firm v mattress warehouse',
#  'big mattress sale',
#  'buy queen size mattress online',
#  'cheap mattress cleveland ohio',
#  'chicago mattress co',
#  'dream factory outlet',
#  'full size mattress sale near',
#  'bed free mattress',
#  'memory foam near',
#  'foam outlet near',
#  'online mattress shop',
#  'mattress firm clearance center houston',
#  'cheap mattress sale',
#  'best time year mattress sale',
#  'veteran day bed sale',
#  'buy bed mattress',
#  'double bed mattress deal',
#  'cheap full mattress near',
#  'mattress firm denver',
#  'futon baltimore',
#  'mattress plus near',
#  'mattress sale portland',
#  'foam sale cheap',
#  'mattress',
#  'memorial weekend mattress sale',
#  'bed sale weekend',
#  'best online mattress deal',
#  'mattress lowest price',
#  'buy one get one free mattress',
#  'mattress deal near',
#  'best time buy new mattress',
#  'bed plus mattress sale',
#  'best buy ad',
#  'buy pillow top mattress',
#  'mattress one veteran day sale',
#  'bed matress sale',
#  'full size bed delivery',
#  'mattress firm warehouse san antonio',
#  'get good mattress cheap',
#  'matress sale near',
#  'futon columbus ohio',
#  'bed sale nyc',
#  'macy president day mattress sale',
#  'mattress bed set',
#  'macy mattress sale date',
#  'open box coupon best buy',
#  'buy mattress online usa',
#  'macy mattress store locator',
#  'buy mattress near',
#  'macys mattress',
#  'cheapest place get mattress',
#  'best priced mattress store',
#  'star mattress furniture',
#  'king mattress sale near',
#  'mattress discount warehouse',
#  'serta mattress warehouse',
#  'right futon chicago',
#  'mattress firm louisville ky',
#  'bed matress set',
#  'mattress firm cleveland ohio',
#  'u mattress sale',
#  'next day mattress delivery',
#  'queen mattress set costco',
#  'best mattress deal near',
#  'cheap mattress online free shipping',
#  'mattress offer',
#  'next day deal',
#  'best mattress cheapest price',
#  'budget mattress outlet columbus ohio',
#  'new mattress near',
#  'month best time buy mattress',
#  'queen mattress sale free delivery',
#  'buying bed mattress',
#  'discount bed store near',
#  'mattress warehouse pittsburgh',
#  'best month buy mattress',
#  'mattress outlet online',
#  'best time buy bed',
#  'best low priced mattress',
#  'mattress warehouse free tv',
#  'mattress sale cheap',
#  'best buy columbus day sale',
#  'special mattress',
#  'cariloha san antonio',
#  'used mattress sale near',
#  'ltd hybrid ii',
#  'cheapest place buy mattress set',
#  'mattress warehouse houston',
#  'discount mattress near',
#  'mattress firm discount center',
#  'mattress outlet dallas tx',
#  'macy labor day mattress sale',
#  'cheap mattress sale near',
#  'best mattress sale weekend',
#  'end year mattress sale',
#  'bed mattress set sale',
#  'memorial mattress sale',
#  'mattress firm year end sale',
#  'best mattress delivery',
#  'top mattress store',
#  'mattress outlet seattle',
#  'best bed online',
#  'tempur pedic dr inc',
#  'best time buy mattress sale',
#  'single mattress sale',
#  'cheap mattress jacksonville fl',
#  'mattress sale nearby',
#  'queen mattress set',
#  'mattress store close',
#  'mattress one spring tx',
#  'mattress com',
#  'mattress delivery seattle',
#  'mattress sale macys',
#  'king size clothes coupon',
#  'mattress sale macy',
#  'buy mattress online free shipping',
#  'mattress warehouse mattress sale',
#  'big bed sale',
#  'mattress warehouse philadelphia',
#  'top rated mattress store',
#  'single mattress cheap',
#  'macys full size mattress',
#  'macys mattress queen',
#  'portland mattress outlet',
#  'find cheap mattress near',
#  'mattress firm black friday',
#  'macy mattress queen',
#  'small mattress sale',
#  'mattress warehouse coupon',
#  'best mattress sale labor day weekend',
#  'mattress firm clearance jacksonville fl',
#  'macys sale today',
#  'mattress deal memorial day',
#  'low cost mattress online',
#  'online mattress store',
#  'mattress sale online free shipping',
#  'macy queen mattress set sale',
#  'columbus day bed sale',
#  'discount mattress box spring',
#  'mattress store location',
#  'mattress firm outlet houston',
#  'buy buy mattress',
#  'great mattress deal',
#  'matress store near',
#  'oh home plush',
#  'mattress sale july',
#  'holiday mattress sale',
#  'mattress sale',
#  'bed mattress set cheap',
#  'floor mattress queen',
#  'cheapest bed mattress',
#  'best month buy new mattress',
#  'chicago mattress outlet',
#  'firm mattress sale',
#  'queen mattress box spring',
#  'cheapest full mattress set',
#  'bed mattress included cheap',
#  'sleep store near',
#  'new mattress cheap',
#  'macy mattress sale today',
#  'mattress firm closeout',
#  'discount mattress free shipping',
#  'online mattress outlet',
#  'best mattress best price',
#  'mattress warehouse san antonio',
#  'best mattress set',
#  'mattress warehouse clearance outlet',
#  'huge bed sale',
#  'mattress firm clearance',
#  'mattress store near',
#  'mattress firm spring tx',
#  'best queen mattress',
#  'futon mattress tulsa',
#  'biggest mattress',
#  'memory foam mattress sale near',
#  'mattres mattres',
#  'cheap brand new mattress',
#  'best buy en queen',
#  'costco mattress queen',
#  'macys com mattress',
#  'mattress free delivery',
#  'ltd clearance',
#  'serta promotion',
#  'cheap single mattress sale',
#  'great mattress cheap',
#  'president day sale mattress',
#  'mattress firm president sale',
#  'mattress today',
#  'louisville bedding company latex pillow',
#  'matress deal',
#  'best time buy mattress macy',
#  'best place buy mattress near',
#  'mattress firm doorbuster sale',
#  'mattress sell',
#  'sale bed mattress',
#  'best mattress offer',
#  'mattress sale clearance',
#  'sealy serta mattress best',
#  'twin mattress okc',
#  'memorial day mattress sale near',
#  'mattress sale memorial day weekend',
#  'futon store philadelphia',
#  'mattress firm denver co',
#  'free delivery mattress warehouse',
#  'best time buy mattress box spring',
#  'online mattress sale',
#  'best price quality mattress',
#  'buy affordable mattress',
#  'best buy mattress sale',
#  'mother day mattress sale',
#  'u mattress memorial day sale',
#  'store matress',
#  'buy cheap mattress set',
#  'best mattress deal weekend',
#  'free shipping mattress',
#  'get best deal mattress',
#  'doctor choice plush mattress',
#  'purple mattress coupon',
#  'mattress store deliver',
#  'twin bargain',
#  'mattress firm doorbuster',
#  'bed sale today',
#  'mattress sale free delivery',
#  'discount mattress dallas',
#  'size difference full queen',
#  'mattress online free shipping',
#  'biggest mattress buy',
#  'bed mattress deal',
#  'mattress source st louis',
#  'long pillow top mattress last',
#  'warehouse mattress sale',
#  'denver mattress labor day sale',
#  'online matress',
#  'mattress firm labor day sale',
#  'mattress clearance houston',
#  'bed mattress sale cheap',
#  'mattress firm near',
#  'better mattress sealy serta',
#  'cheap mattress deal',
#  'best mattress sale',
#  'back bed store',
#  'mattress firm deliver',
#  'best place buy mattress cheap',
#  'macy columbus day mattress sale',
#  'foam sale near',
#  'mattress sale weekend',
#  'best cheapest mattress',
#  'discount boxspring',
#  'biggest mattress size',
#  'discount mattress store near',
#  'discounted mattress near',
#  'good mattress price',
#  'mattress low price',
#  'mattress delivery near',
#  'houston mattress sale',
#  'denver mattress purple',
#  'macy july mattress sale',
#  'inch mattress',
#  'macys mattress king',
#  'purple mattress black friday',
#  'best price matress',
#  'mattress sale week',
#  'platinum dream mattress',
#  'labor day mattress sale',
#  'mattress doorbuster',
#  'biggest mattress sale year',
#  'mattress firm president day sale',
#  'new mattress',
#  'sealy coupon',
#  'best priced mattress',
#  'mattress sale going',
#  'best deal mattress',
#  'mattress coupon',
#  'macy queen mattress',
#  'mattress mattress',
#  'best delivery mattress',
#  'chicago mattress warehouse',
#  'cheap mattress online',
#  'futon cleveland ohio',
#  'store sale',
#  'king size mattress free shipping',
#  'cheap bed mattress sale',
#  'macy veteran day mattress sale',
#  'mattress queen',
#  'cheap mattress place near',
#  'mattress tv deal',
#  'cheap mattress free shipping',
#  'cheapest bed sale',
#  'sealy v serta',
#  'mattress king memorial day sale',
#  'president day mattress sale',
#  'macy one day mattress sale',
#  'mattres',
#  'foam mattress store near',
#  'mattress cheap online',
#  'better price mattress',
#  'macy full size mattress',
#  'mattress macys sale',
#  'serta president day sale',
#  'tucson mattress sale',
#  'mattress firm',
#  'mattress firm clearance center location',
#  'serta coupon',
#  'full size mattress set free delivery',
#  'sleep train president day sale',
#  'queen size mattress online',
#  'extra firm futon mattress',
#  'macy mattress sale',
#  'queen mattress set free delivery',
#  'puffy twin mattress',
#  'denver mattress doctor choice plush',
#  'buy cheap mattress',
#  'mattress clearance dallas',
#  'buy new mattress',
#  'nectar mattress near',
#  'best time buy tempurpedic mattress',
#  'bed deal',
#  'mattress sale online',
#  'weekend furniture mattress',
#  'bed mattress included sale',
#  'mattress firm philadelphia',
#  'upcoming mattress sale',
#  'new bed mattress price',
#  'mattress warehouse columbus',
#  'discount mattress store',
#  'best buy closeout',
#  'sleep shop near',
#  'mattress king denver',
#  'mattress sale area',
#  'oc mattress king',
#  'cheapest mattress price',
#  'mattress warehouse president day sale',
#  'best buy near queen',
#  'memorial day matress sale',
#  'mattress clearance store',
#  'buy good mattress cheap',
#  'mattress near cheap',
#  'memorial day sale mattress',
#  'memory foam talk',
#  'deal bed coupon',
#  'macys sa',
#  'mattress firm pillow coupon',
#  'looking mattress',
#  'leesa mattress nyc',
#  'silver dream mattress',
#  'mattress firm free delivery coupon',
#  'buy mattress set',
#  'best time purchase mattress',
#  'futon mattress colorado spring',
#  'mattress place near',
#  'discount quality mattress',
#  'mattress firm special',
#  'mattress clearance chicago',
#  'discount memory foam matress',
#  'biggest bed sale',
#  'best firm mattress',
#  'memory foam mattress cheapest',
#  'mattress sale chattanooga',
#  'mattress sale cleveland ohio',
#  'futon mattress nyc',
#  'simmons outlet near',
#  'mattress one memorial day sale',
#  'cheap mattress set online',
#  'labor day weekend mattress sale',
#  'mattress sale near location',
#  'king mattress clearance sale',
#  'cheap new mattress boxspring set',
#  'macy twin mattress sale',
#  'best mattress deal today',
#  'macy mattress department',
#  'sell cheapest mattress',
#  'cheapest mattress near',
#  'mattress king warehouse',
#  'mattress free shipping',
#  'google mattress',
#  'mattress outlet',
#  'mattress firm columbus ohio',
#  'macys bed sale',
#  'firm mattress near',
#  'denver mattress king',
#  'murfreesboro mattress store',
#  'twin full mattress',
#  'best king mattress',
#  'best time year buy mattress',
#  'mattress sale free tv',
#  'best full size mattress money',
#  'best time year buy mattress sale',
#  'queen size mattress macys',
#  'buy mattress online',
#  'mattress n',
#  'mattress sale cheap price',
#  'three quarter bed set',
#  'discount mattress',
#  'mattress store sale',
#  'brand name mattress',
#  'best plush mattress',
#  'bed mattress near',
#  'price mattress',
#  'la vega mattress outlet',
#  'buy mattress online cheap',
#  'bed mattress sale near',
#  'bed mattress set',
#  'full mattress free shipping',
#  'queen box spring dallas',
#  'best mattress box spring set',
#  'serta sealy',
#  'futon mattress houston',
#  'king beauty supply louisville ky',
#  'cheap good mattress set',
#  'matress discount',
#  'pick mattress',
#  'cheapest mattress sale',
#  'super discount mattress warehouse',
#  'best mattress deal online',
#  'queen size mattress box moving',
#  'online mattress sale usa',
#  'mattress best buy',
#  'cheap mattress store near',
#  'inexpensive mattress sale',
#  'sealy mattress coupon',
#  'cheapest place buy mattress box spring',
#  'discount mattress sale',
#  'king size mattress delivered',
#  'mattress firm deal',
#  'best mattress deal memorial day',
#  'best mattress deal',
#  'best bed',
#  'dallas mattress outlet',
#  'denver mattress twin',
#  'foam mattress sale',
#  'macy mattress set',
#  'dream bed mattress firm',
#  'bed free delivery',
#  'memorial day weekend mattress sale',
#  'queen mattress set sale free shipping',
#  'cheap mattress free delivery',
#  'affordable mattress online',
#  'best mattress labor day sale',
#  'best mattress store',
#  'discount mattress set',
#  'good deal bed mattress',
#  'mattress online delivery',
#  'cheapest foam mattress',
#  'buy one get one free mattress warehouse',
#  'best deal mattress set',
#  'cheap discount mattress',
#  'day mattress store',
#  'mattresssale',
#  'mattress warehouse san diego',
#  'mattress warehouse sale',
#  'cheap mattress area',
#  'mattress around',
#  'discount matress store',
#  'cheap good mattress sale',
#  'mattress outlet dallas',
#  'mattress firm store coupon',
#  'mattress discount store',
#  'july mattress sale',
#  'queen full mattress',
#  'discount mattress firm',
#  'veteran day sale mattress',
#  'sale mattress near',
#  'full mattress free delivery',
#  'mattress firm pittsburgh',
#  'mattress sale columbus day',
#  'mattress warehouse plus',
#  'u mattress com coupon',
#  'best mattress price near',
#  'best mattress sealy serta',
#  'best place buy cheap mattress',
#  'cheap new bed near',
#  'mattress outlet denver',
#  'queen mattress macys',
#  'cheapest place mattress',
#  'mattress firm ad',
#  'mattress sale jacksonville fl',
#  'denver mattress box spring',
#  'best bed buy online',
#  'mattress outlet store',
#  'mattress firm columbus oh',
#  'low price mattress near',
#  'serta sealy mattress',
#  'mattress firm colorado',
#  'overstock mattress set',
#  'brand new mattress sale',
#  'good mattress sale',
#  'king size mattress sale costco',
#  'mattress financing',
#  'beautyrest coupon',
#  'mattress firm sale flyer',
#  'mattress sale okc',
#  'mattress firm sale ad',
#  'mattress one clearance',
#  'mattress store rating',
#  'mattress outlet houston',
#  'discount mattress okc',
#  'good mattress deal',
#  'mattress warehouse labor day sale',
#  'mattress warehouse baltimore',
#  'complete bed set mattress',
#  'best buy labor day weekend sale',
#  'memorial day mattress',
#  'full mattress sale free shipping',
#  'bed sale free delivery',
#  'new year mattress sale',
#  'mattress discount online',
#  'simmons mattress outlet dallas',
#  'mattress firm adjustable base',
#  'find cheap mattress',
#  'mattress sale veteran day',
#  'bed mattress online',
#  'mattress right',
#  'mattress firm clearance outlet',
#  'cheap new mattress near',
#  'best semi firm mattress',
#  'discount mattress tulsa',
#  'full mattress delivery',
#  'best time buy new bed',
#  'mattress outlet near',
#  'macy mattress sale coupon',
#  'discount mattress tucson',
#  'best premium mattress',
#  'mattress offer online',
#  'brand new mattress cheap',
#  'venta de colchones en macy',
#  'serta warehouse location',
#  'store sell mattress near',
#  'new mattress box',
#  'macy mattress set sale',
#  'mattress sale price',
#  'online mattress store free delivery',
#  'discount mattress store jacksonville fl',
#  'mattress stock near',
#  'best place get cheap mattress',
#  'foam mattress warehouse',
#  'mattress sale houston',
#  'delivery mattress',
#  'mattress firm memorial day sale',
#  'cheap bed matress deal',
#  'buy cheapest mattress online',
#  'mattress sale dfw',
#  'mattress clearance outlet',
#  'dream home furniture columbus ohio',
#  'three quarter mattress',
#  'columbus day mattress sale',
#  'sealy serta simmons',
#  'mattress outlet portland',
#  'mattress best time buy',
#  'best price mattress',
#  'cheap good bed sale',
#  'best price mattress near',
#  'mattress firm clearance near',
#  'place get cheap mattress',
#  'mattress firm louisville kentucky',
#  'macys mattress outlet',
#  'best mattress near',
#  'houston discount mattress',
#  'mattress warehouse houston tx',
#  'free tv mattress purchase',
#  'best king size mattress',
#  'day bed mattress',
#  'mattress box cheap',
#  'sell mattress cheap',
#  'store sell mattress',
#  'bed sale mattress',
#  'mattress warehouse louisville',
#  'full mattress cheap',
#  'mattressnow',
#  'best mattress shop',
#  'find mattress store near',
#  'single mattress near',
#  'mattress dollar',
#  'much sell mattress',
#  'best mattress sale memorial day',
#  'top mattress',
#  'queen mattress store',
#  'mattress com coupon',
#  'low cost mattress boxspring',
#  'macys mattress twin',
#  'best matress sale',
#  'firm bed sale',
#  'mattress warehouse nyc',
#  'mattress warehouse near',
#  'cheapest mattress store',
#  'cheap mattress delivery',
#  'firm mattress online',
#  'colchones tempur pedic',
#  'mattress warehouse louisville ky',
#  'mattress queen king',
#  'best mattress sale today',
#  'mattres sale',
#  'mattress firm cleveland',
#  'twin mattress futon',
#  'simmons outlet dallas',
#  'mattress firm warehouse denver',
#  'mattress deal online',
#  'sale mattress',
#  'best mattress sale year',
#  'matte sale',
#  'double bed mattress sale',
#  'mattress set deal',
#  'cheap mattress near',
#  'cheap bed mattress included',
#  'denver mattress tulsa ok',
#  'mattress clearance usa',
#  'serta denver',
#  'mattress clearance sale',
#  'colchones sleeping',
#  'sealy serta better',
#  'free delivery mattress',
#  'labor day sale mattress',
#  'mattress clearance near',
#  'best mattress',
#  'mattress store cleveland',
#  'find mattress sale',
#  'mattress business sale',
#  'king size floor mattress',
#  'president sale mattress',
#  'mattress firm sale houston',
#  'biggest size mattress',
#  'best mattress firm',
#  'mattress warehouse jacksonville fl',
#  'matress',
#  'cheap bed mattress',
#  'new mattress sale',
#  'best memorial day mattress sale',
#  'best time year buy new mattress',
#  'cheapest full mattress',
#  'cheap queen mattress set near',
#  'best pillow top mattress',
#  'best matress deal',
#  'big mattress',
#  'mattress warehouse black friday sale',
#  'mattress warehouse st louis',
#  'cheap name brand mattress',
#  'best time buy mattress',
#  'online mattress shopping',
#  'mattress firm sale weekend',
#  'mattress sale nyc',
#  'u mattresscom coupon',
#  'columbus day sale best buy',
#  'ultra sale ad',
#  'leesa mattress shipping time',
#  'matresses near',
#  'sealy posturepedic v serta perfect sleeper',
#  'bed special',
#  'mattress firm warehouse columbus ohio',
#  'free mattress near',
#  'low price bed mattress',
#  'mattress source location',
#  'mattress firm clearance houston tx',
#  'discount mattress baltimore md',
#  'mattress king',
#  'mattress macys',
#  'macy bed mattress',
#  'mattress firm louisville',
#  'mattress veteran day sale',
#  'denver mattress memorial day sale',
#  'mattress source',
#  'mattress firm finance',
#  'mattress sale pa',
#  'mismatched mattress sale',
#  'mattress place',
#  'discount mattress boxspring set',
#  'mattress firm corpus christi tx',
#  'foam mattress discount',
#  'home plush oh',
#  'best buy furniture pa',
#  'usa mattress outlet',
#  'nectar mattress showroom',
#  'mattress firm seattle',
#  'queen mattress clearance free shipping',
#  'macy mattress sale full size',
#  'mattress sale labor day',
#  'mattress sa',
#  'discount mattress online',
#  'mattress sale denver',
#  'macys mattress full',
#  'next day mattress',
#  'cheapest best mattress',
#  'deal mattress',
#  'memory foam cheapest',
#  'mattress firm portland',
#  'mattress warehouse chicago',
#  'memory foam mattress cheapest price',
#  'cheap double size mattress',
#  'best buy sale',
#  'macys matress',
#  'cheap mattress set near',
#  'place sell mattress',
#  'full mattress online',
#  'cheap single bed mattress sale',
#  'macy mattress outlet',
#  'warehouse clearance mattress',
#  'california mattress company',
#  'denver mattress sale',
#  'mattress warehouse tucson',
#  'mattress firm outlet',
#  'easter mattress sale',
#  'bed sale near',
#  'christmas mattress sale',
#  'king size futon set',
#  'foam mattress clearance',
#  'buy cheap mattress near',
#  'sealy serta',
#  'macys matresses',
#  'best mattress queen',
#  'mattress firm outlet store',
#  'simmons beautyrest v serta perfect sleeper',
#  'mattress store near cheap',
#  'sealy sweet sleeper mattress',
#  'memory foam mattress warehouse',
#  'buy bed mattress online',
#  'premium mattress outlet inc',
#  'mattress outlet inc',
#  'bed mattress sale',
#  'veteran day mattress sale',
#  'best deal bed mattress',
#  'macy mattress sale queen',
#  'king futon',
#  'best low cost mattress',
#  'affordable mattress inc',
#  'mattress le near',
#  'mattress macy',
#  'buy mattress set online',
#  'l mattress',
#  'mattress sale houston texas',
#  'mattress outlet store near',
#  'buy furniture foam',
#  'sealy dream bed',
#  'bed sale houston',
#  'mattress firm july sale',
#  'mattress warehouse king size mattress',
#  'cheap double mattress sale',
#  'shopping mattress tip',
#  'best matress price',
#  'mattress best deal',
#  'cheapest place buy mattress online',
#  'mattress special near',
#  'mattress warehouse houston texas',
#  'low cost mattress set',
#  'mattress clearance warehouse',
#  'mismatch mattress sale',
#  'macy black friday mattress sale',
#  'top online mattress',
#  'memory foam mattress coupon',
#  'top mattress deal',
#  'sealy factory outlet',
#  'mattress sale president day',
#  'biggest matress size',
#  'mattress discount',
#  'mattress twin fall idaho',
#  'firm mattress deal',
#  'macys com mattress sale',
#  'free mattress delivery',
#  'macy bed mattress sale',
#  'cheap new mattress',
#  'memory foam mattress free shipping',
#  'sleepy mattress deal',
#  'sealy mattress warehouse',
#  'mattress sale houston tx',
#  'serta posturepedic gel series',
#  'cheap new bed mattress',
#  'mattress firm okc ok',
#  'best place buy mattress',
#  'mattress bed sale',
#  'mattress warehouse colorado spring',
#  'talk today deal',
#  'inexpensive mattress near',
#  'macy matress',
#  'denver discount mattress',
#  'mattress firm location ohio',
#  'super single mattress sale',
#  'best mattress deal memorial day weekend',
#  'mismatched mattress',
#  'mattress firm king size mattress price',
#  'tempurpedic mattress closeout sale',
#  'macys mattress sale',
#  'queen mattress online',
#  'mattress close',
#  'mattress firm san francisco',
#  'matress near',
#  'mattress store murfreesboro',
#  'affordable bed mattress',
#  'foam mattress near',
#  'philadelphia mattress company',
#  'coupon queen tulsa',
#  'macy matress sale',
#  'denver mattress san antonio texas',
#  'mattress cleveland ohio',
#  'mattress warehouse financing',
#  'mattress firm murfreesboro',
#  'affordable mattress near',
#  'serta mattress factory outlet',
#  'mattress sale mn',
#  'macy mattress clearance',
#  'mattress set free delivery',
#  'cheap king size bed mattress included',
#  'today show mattress',
#  'mattress firm portland tx',
#  'denver mattress president day sale',
#  'mattress king coupon',
#  'mattress sale around',
#  'bed store around',
#  'shop mattress online',
#  'mattress sale near',
#  'cheap mattress set',
#  'cheap mattress full',
#  'luxury mattress online',
#  'mattress firm clearance center',
#  'cheap full mattress',
#  'sealy serta mattress',
#  'macys matress sale',
#  'bed mattress set deal',
#  'purple mattress sample',
#  'low price mattress sale',
#  'single mattress best price',
#  'cheap top mattress',
#  'mattress king tulsa',
#  'cheap mattress set sale',
#  'mattress outlet jacksonville fl',
#  'sell bed mattress',
#  'box spring san diego',
#  'mattress sale jacksonville',
#  'day mattress',
#  'mattress silver spring',
#  'mattress one warehouse houston',
#  'mattress deal today',
#  'outlet mattress store',
#  'macy mattress store',
#  'cheapest mattress',
#  'mattress online free delivery',
#  'mattress firm dream bed',
#  'coupon king size',
#  'king size mattress set',
#  'discount mattress set near',
#  'mattress firm columbus day sale',
#  'new mattress set',
#  'macy venta de colchones',
#  'paramount promotion sealy tx',
#  'best mattress price',
#  'best mattress mattress firm',
#  'looking mattress sale',
#  'name brand mattress',
#  'mattress firm fourth july sale',
#  'macys bedding sale',
#  'mattress buy',
#  'free adjustable base mattress firm',
#  'mattress firm mattress sale',
#  'mattress one heath ohio',
#  'cheap affordable mattress',
#  'mattress firm denver colorado',
#  'portland mattress sale',
#  'discount mattress portland',
#  'mattress firm clearance store',
#  'mattress store around',
#  'new mattress price',
#  'single size mattress sale',
#  'mattress one day delivery',
#  'jacksonville mattress store',
#  'discount mattress la vega',
#  'san diego mattress warehouse',
#  'ups store sale california',
#  'max dallas',
#  'mattress set sale near',
#  'macy mattress sale king size',
#  'place sell mattress near',
#  'beautyrest dream sleep mattress',
#  'simmons mattress factory outlet',
#  'mattress warehouse cleveland',
#  'mattress sale cleveland',
#  'cheap mattress set cleveland ohio',
#  'mattress online cheap',
#  'mattress store free delivery',
#  'current mattress sale',
#  ...]

# %%
len(distinct_keywords)
# Out:
# 1137

# %% [markdown]
# ### 3.3 Find Keywords Similarity
# We use Levenshtein distance. This distance is computed by finding the number of edits which will transform one string to another. The transformations allowed are insertion — adding a new character, deletion — deleting a character and substitution — replace one character by another. By performing these three operations, the algorithm tries to modify first string to match the second one.

# %%
# find similar keyword by applying levensthein algorithm with simillarity threshold value between 0.91 and 1.
# the output is in list of tuple of the keywords and its similar words

def keywords_matching(the_keywords):
    start = time.time()
    
    similar_keywords = list()
    copy_distinct_keywords = the_keywords
    for keywords in distinct_keywords:
        for idx in range (len(copy_distinct_keywords)):
            if 0.91 <= textdistance.levenshtein.normalized_similarity(keywords, distinct_keywords[idx]) < 1.0:
                similar_keywords.append((keywords, distinct_keywords[idx]))
          
    print('Total time: ' + str((time.time() - start)) + ' secs')
    return similar_keywords

# %%
similar_keywords = keywords_matching(distinct_keywords)
# Out:
# Total time: 2846.1817483901978 secs

# %%
similar_keywords
# Out:
# [('new mattress sale cheap', 'bed mattress sale cheap'),
#  ('macys mattress store', 'macy mattress store'),
#  ('best time buy matress', 'best time buy mattress'),
#  ('matress sale', 'mattress sale'),
#  ('futon mattress stlouis', 'futon mattress st louis'),
#  ('matteress sale', 'mattress sale'),
#  ('cheap bed mattress deal', 'cheap bed matress deal'),
#  ('macy bed sale', 'macys bed sale'),
#  ('macys mattress sale date', 'macy mattress sale date'),
#  ('bed matress sale', 'bed mattress sale'),
#  ('matress sale near', 'mattress sale near'),
#  ('macy mattress sale date', 'macys mattress sale date'),
#  ('macys mattress', 'macys matress'),
#  ('macys mattress', 'macy mattress'),
#  ('bed matress set', 'bed mattress set'),
#  ('u mattress sale', 'w mattress sale'),
#  ('best low priced mattress', 'best low price mattress'),
#  ('used mattress sale near', 'bed mattress sale near'),
#  ('discount mattress near', 'discounted mattress near'),
#  ('mattress sale macys', 'mattress sale macy'),
#  ('mattress sale macy', 'mattress sale macys'),
#  ('macys full size mattress', 'macy full size mattress'),
#  ('macys mattress queen', 'macy mattress queen'),
#  ('macy mattress queen', 'macys mattress queen'),
#  ('online mattress store', 'online matress store'),
#  ('matress store near', 'mattress store near'),
#  ('mattress sale', 'matress sale'),
#  ('mattress sale', 'matteress sale'),
#  ('mattress sale', 'mattresssale'),
#  ('mattress sale', 'mattres sale'),
#  ('mattress store near', 'matress store near'),
#  ('matress deal', 'mattress deal'),
#  ('u mattress memorial day sale', 'mattress memorial day sale'),
#  ('bed mattress sale cheap', 'new mattress sale cheap'),
#  ('mattress firm near', 'matress firm near'),
#  ('best mattress sale', 'best matress sale'),
#  ('biggest mattress size', 'biggest matress size'),
#  ('discounted mattress near', 'discount mattress near'),
#  ('best price matress', 'best price mattress'),
#  ('best priced mattress', 'best price mattress'),
#  ('macy full size mattress', 'macys full size mattress'),
#  ('macy mattress sale', 'macys mattress sale'),
#  ('macy mattress sale', 'macy matress sale'),
#  ('discount mattress store', 'discount matress store'),
#  ('memorial day matress sale', 'memorial day mattress sale'),
#  ('mattress firm columbus ohio', 'mattress firm columbus oh'),
#  ('macys bed sale', 'macy bed sale'),
#  ('best king mattress', 'best king matress'),
#  ('bed mattress sale near', 'used mattress sale near'),
#  ('bed mattress sale near', 'best mattress sale near'),
#  ('bed mattress set', 'bed matress set'),
#  ('matress discount', 'mattress discount'),
#  ('best mattress deal', 'best matress deal'),
#  ('macy mattress set', 'macys mattress set'),
#  ('mattresssale', 'mattress sale'),
#  ('mattresssale', 'mattres sale'),
#  ('discount matress store', 'discount mattress store'),
#  ('u mattress com coupon', 'u mattresscom coupon'),
#  ('mattress firm columbus oh', 'mattress firm columbus ohio'),
#  ('cheap bed matress deal', 'cheap bed mattress deal'),
#  ('best price mattress', 'best price matress'),
#  ('best price mattress', 'best priced mattress'),
#  ('macys mattress outlet', 'macy mattress outlet'),
#  ('best matress sale', 'best mattress sale'),
#  ('mattres sale', 'mattress sale'),
#  ('mattres sale', 'mattresssale'),
#  ('best mattress sale year', 'best mattress sale near'),
#  ('best matress deal', 'best mattress deal'),
#  ('best time buy mattress', 'best time buy matress'),
#  ('u mattresscom coupon', 'u mattress com coupon'),
#  ('mattress macys', 'mattress macy'),
#  ('mismatched mattress sale', 'mismatch mattress sale'),
#  ('macys matress', 'macys mattress'),
#  ('macys matress', 'macy matress'),
#  ('macy mattress outlet', 'macys mattress outlet'),
#  ('mattress firm outlet', 'matress firm outlet'),
#  ('bed mattress sale', 'bed matress sale'),
#  ('affordable mattress inc', 'affordable mattress nyc'),
#  ('mattress macy', 'mattress macys'),
#  ('best matress price', 'best mattress price'),
#  ('mismatch mattress sale', 'mismatched mattress sale'),
#  ('biggest matress size', 'biggest mattress size'),
#  ('mattress discount', 'matress discount'),
#  ('macy matress', 'macys matress'),
#  ('macy matress', 'macy mattress'),
#  ('macys mattress sale', 'macy mattress sale'),
#  ('macys mattress sale', 'macys matress sale'),
#  ('macy matress sale', 'macy mattress sale'),
#  ('macy matress sale', 'macys matress sale'),
#  ('mattress sale near', 'matress sale near'),
#  ('macys matress sale', 'macys mattress sale'),
#  ('macys matress sale', 'macy matress sale'),
#  ('macy mattress store', 'macys mattress store'),
#  ('best mattress price', 'best matress price'),
#  ('affordable mattress nyc', 'affordable mattress inc'),
#  ('matress firm near', 'mattress firm near'),
#  ('futon mattress st louis', 'futon mattress stlouis'),
#  ('best king matress', 'best king mattress'),
#  ('memorial day mattress sale', 'memorial day matress sale'),
#  ('mattress deal', 'matress deal'),
#  ('matress firm outlet', 'mattress firm outlet'),
#  ('macy mattress', 'macys mattress'),
#  ('macy mattress', 'macy matress'),
#  ('w mattress sale', 'u mattress sale'),
#  ('best mattress sale near', 'bed mattress sale near'),
#  ('best mattress sale near', 'best mattress sale year'),
#  ('macys mattress set', 'macy mattress set'),
#  ('online matress store', 'online mattress store'),
#  ('mattress memorial day sale', 'u mattress memorial day sale'),
#  ('best low price mattress', 'best low priced mattress')]

# %%
df_similar_keyword = pd.DataFrame(similar_keywords, columns=['keyword', 'similar keyword'])

# %%
df_similar_keyword
# Out:
#                         keyword               similar keyword
# 0       new mattress sale cheap       bed mattress sale cheap
# 1          macys mattress store           macy mattress store
# 2         best time buy matress        best time buy mattress
# 3                  matress sale                 mattress sale
# 4        futon mattress stlouis       futon mattress st louis
# 5                matteress sale                 mattress sale
# 6       cheap bed mattress deal        cheap bed matress deal
# 7                 macy bed sale                macys bed sale
# 8      macys mattress sale date       macy mattress sale date
# 9              bed matress sale             bed mattress sale
# 10            matress sale near            mattress sale near
# 11      macy mattress sale date      macys mattress sale date
# 12               macys mattress                 macys matress
# 13               macys mattress                 macy mattress
# 14              bed matress set              bed mattress set
# 15              u mattress sale               w mattress sale
# 16     best low priced mattress       best low price mattress
# 17      used mattress sale near        bed mattress sale near
# 18       discount mattress near      discounted mattress near
# 19          mattress sale macys            mattress sale macy
# 20           mattress sale macy           mattress sale macys
# 21     macys full size mattress       macy full size mattress
# 22         macys mattress queen           macy mattress queen
# 23          macy mattress queen          macys mattress queen
# 24        online mattress store          online matress store
# 25           matress store near           mattress store near
# 26                mattress sale                  matress sale
# 27                mattress sale                matteress sale
# 28                mattress sale                  mattresssale
# 29                mattress sale                  mattres sale
# ..                          ...                           ...
# 80       mismatch mattress sale      mismatched mattress sale
# 81         biggest matress size         biggest mattress size
# 82            mattress discount              matress discount
# 83                 macy matress                 macys matress
# 84                 macy matress                 macy mattress
# 85          macys mattress sale            macy mattress sale
# 86          macys mattress sale            macys matress sale
# 87            macy matress sale            macy mattress sale
# 88            macy matress sale            macys matress sale
# 89           mattress sale near             matress sale near
# 90           macys matress sale           macys mattress sale
# 91           macys matress sale             macy matress sale
# 92          macy mattress store          macys mattress store
# 93          best mattress price            best matress price
# 94      affordable mattress nyc       affordable mattress inc
# 95            matress firm near            mattress firm near
# 96      futon mattress st louis        futon mattress stlouis
# 97            best king matress            best king mattress
# 98   memorial day mattress sale     memorial day matress sale
# 99                mattress deal                  matress deal
# 100         matress firm outlet          mattress firm outlet
# 101               macy mattress                macys mattress
# 102               macy mattress                  macy matress
# 103             w mattress sale               u mattress sale
# 104     best mattress sale near        bed mattress sale near
# 105     best mattress sale near       best mattress sale year
# 106          macys mattress set             macy mattress set
# 107        online matress store         online mattress store
# 108  mattress memorial day sale  u mattress memorial day sale
# 109     best low price mattress      best low priced mattress
#
# [110 rows x 2 columns]

# %%
df_similar_keyword.to_csv('similar_keywords.csv')
